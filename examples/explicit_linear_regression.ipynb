# %% [markdown]
# ## Regular ACE
# Really just copy/paste of AF's implementation in `pyro`. Since the current `pyro` release doesn't have some of AF's code from SGBOED, have to copy/paste some of his custom functions here.
#
# Going to compare the lower/upper bounds of SGBOED on a simple linear regression task.

# %%
import time
import numbers
import math

import torch
from torch import nn
from torch.distributions import constraints

import pyro
import pyro.distributions as dist
import pyro.optim as optim
from pyro import poutine
from pyro.contrib.util import rmv, lexpand

def is_bad(a):
    return torch_isnan(a) or torch_isinf(a)
    

def torch_isnan(x):
    """
    A convenient function to check if a Tensor contains any nan; also works with numbers
    """
    if isinstance(x, numbers.Number):
        return x != x
    return torch.isnan(x).any()


def torch_isinf(x):
    """
    A convenient function to check if a Tensor contains any +inf; also works with numbers
    """
    if isinstance(x, numbers.Number):
        return x == float('inf') or x == -float('inf')
    return (x == float('inf')).any() or (x == -float('inf')).any()


def _safe_mean_terms(terms):
    mask = torch.isnan(terms) | (terms == float('-inf')) | (terms == float('inf'))
    if terms.dtype is torch.float32:
        nonnan = (~mask).sum(0).float()
    elif terms.dtype is torch.float64:
        nonnan = (~mask).sum(0).double()
    terms[mask] = 0.
    loss = terms.sum(0) / nonnan
    agg_loss = loss.sum()
    return agg_loss, loss


def make_regression_model(w_loc, w_scale, sigma_scale, xi_init, observation_label="y"):
    def regression_model(design_prototype):
        design = pyro.param("xi", xi_init)
        design = (design / design.norm(dim=-1, p=1, keepdim=True)).expand(design_prototype.shape)
        if is_bad(design):
            raise ArithmeticError("bad design, contains nan or inf")
        batch_shape = design.shape[:-2]
        with pyro.plate_stack("plate_stack", batch_shape):
            # `w` is shape p, the prior on each component is independent
            w = pyro.sample("w", dist.Laplace(w_loc, w_scale).to_event(1))
            # `sigma` is scalar
            sigma = 1e-6 + pyro.sample("sigma", dist.Exponential(sigma_scale)).unsqueeze(-1)
            mean = rmv(design, w)
            sd = sigma
            y = pyro.sample(observation_label, dist.Normal(mean, sd).to_event(1))
            return y

    return regression_model


class TensorLinear(nn.Module):
    __constants__ = ['bias']

    def __init__(self, *shape, bias=True):
        super(TensorLinear, self).__init__()
        self.in_features = shape[-2]
        self.out_features = shape[-1]
        self.batch_dims = shape[:-2]
        self.weight = nn.Parameter(torch.Tensor(*self.batch_dims, self.out_features, self.in_features))
        if bias:
            self.bias = nn.Parameter(torch.Tensor(*self.batch_dims, self.out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        if self.bias is not None:
            fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.weight)
            bound = 1 / math.sqrt(fan_in)
            nn.init.uniform_(self.bias, -bound, bound)

    def forward(self, input):
        return rmv(self.weight, input) + self.bias


class PosteriorGuide(nn.Module):
    def __init__(self, y_dim, w_dim, batching):
        super(PosteriorGuide, self).__init__()
        n_hidden = 64
        self.linear1 = TensorLinear(*batching, y_dim, n_hidden)
        self.linear2 = TensorLinear(*batching, n_hidden, n_hidden)
        self.output_layer = TensorLinear(*batching, n_hidden, w_dim + 3)
        self.covariance_shape = batching + (w_dim, w_dim)
        self.softplus = nn.Softplus()
        self.relu = nn.ReLU()

    def forward(self, y_dict, design_prototype, observation_labels, target_labels):
        y = y_dict["y"] - .5
        x = self.relu(self.linear1(y))
        x = self.relu(self.linear2(x))
        final = self.output_layer(x)

        posterior_mean = final[..., :-3]
        gamma_concentration = 1e-6 + self.softplus(final[..., -3])
        gamma_rate = 1. + self.softplus(final[..., -2])
        scale_tril_multiplier = 1e-6 + self.softplus(final[..., -1])

        pyro.module("posterior_guide", self)

        posterior_scale_tril = pyro.param(
            "posterior_scale_tril",
            torch.eye(posterior_mean.shape[-1], device=posterior_mean.device).expand(self.covariance_shape),
            constraint=constraints.lower_cholesky
        )
        posterior_scale_tril = posterior_scale_tril * scale_tril_multiplier.unsqueeze(-1).unsqueeze(-1)

        batch_shape = design_prototype.shape[:-2]
        with pyro.plate_stack("guide_plate_stack", batch_shape):
            pyro.sample("sigma", dist.Gamma(gamma_concentration, gamma_rate))
            pyro.sample("w", dist.MultivariateNormal(posterior_mean, scale_tril=posterior_scale_tril))


def _ace_eig_loss(model, guide, M, observation_labels, target_labels):
    def loss_fn(design, num_particles, evaluation=False, **kwargs):
        N = num_particles
        expanded_design = lexpand(design, N)
        
        # Sample from p(y, theta | d)
        trace = poutine.trace(model).get_trace(expanded_design)
        y_dict_exp = {l: lexpand(trace.nodes[l]["value"], M) for l in observation_labels}
        y_dict = {l: trace.nodes[l]["value"] for l in observation_labels}
        theta_dict = {l: trace.nodes[l]["value"] for l in target_labels}

        trace.compute_log_prob()
        marginal_terms_cross = sum(trace.nodes[l]["log_prob"] for l in target_labels)
        marginal_terms_cross += sum(trace.nodes[l]["log_prob"] for l in observation_labels)

        reguide_trace = poutine.trace(
            pyro.condition(guide, data=theta_dict)).get_trace(
            y_dict, expanded_design, observation_labels, target_labels)
        # Here's a spot where you could update each model's parameters based on log_prob
        reguide_trace.compute_log_prob()
        marginal_terms_cross -= sum(reguide_trace.nodes[l]["log_prob"] for l in target_labels)

        # Sample M times from q(theta | y, d) for each y
        reexpanded_design = lexpand(expanded_design, M)
        guide_trace = poutine.trace(guide).get_trace(
            y_dict, reexpanded_design, observation_labels, target_labels
        )
        theta_y_dict = {l: guide_trace.nodes[l]["value"] for l in target_labels}
        theta_y_dict.update(y_dict_exp)
        guide_trace.compute_log_prob()

        # Re-run that through the model to compute the joint
        model_trace = poutine.trace(
            pyro.condition(model, data=theta_y_dict)).get_trace(reexpanded_design)
        model_trace.compute_log_prob()

        marginal_terms_proposal = -sum(guide_trace.nodes[l]["log_prob"] for l in target_labels)
        marginal_terms_proposal += sum(model_trace.nodes[l]["log_prob"] for l in target_labels)
        marginal_terms_proposal += sum(model_trace.nodes[l]["log_prob"] for l in observation_labels)

        marginal_terms = torch.cat([lexpand(marginal_terms_cross, 1), marginal_terms_proposal])
        terms = -marginal_terms.logsumexp(0) + math.log(M + 1)

        # At eval time, add p(y | theta, d) terms
        if evaluation:
            terms += sum(trace.nodes[l]["log_prob"] for l in observation_labels)
        return _safe_mean_terms(terms)

    return loss_fn


def _vnmc_eig_loss(model, guide, observation_labels, target_labels):
    """VNMC loss: to evaluate directly use `vnmc_eig` setting `num_steps=0`."""

    def loss_fn(design, num_particles, evaluation=False, **kwargs):
        N, M = num_particles
        expanded_design = lexpand(design, N)

        # Sample from p(y, theta | d)
        trace = poutine.trace(model).get_trace(expanded_design)
        y_dict_unexp = {l: trace.nodes[l]["value"] for l in observation_labels}
        y_dict = {l: lexpand(trace.nodes[l]["value"], M) for l in observation_labels}

        # Sample M times from q(theta | y, d) for each y
        reexpanded_design = lexpand(expanded_design, M)
        # conditional_guide = pyro.condition(guide, data=y_dict)
        guide_trace = poutine.trace(guide).get_trace(
            y_dict_unexp, reexpanded_design, observation_labels, target_labels)
        theta_y_dict = {l: guide_trace.nodes[l]["value"] for l in target_labels}
        theta_y_dict.update(y_dict)
        guide_trace.compute_log_prob()

        # Re-run that through the model to compute the joint
        modelp = pyro.condition(model, data=theta_y_dict)
        model_trace = poutine.trace(modelp).get_trace(reexpanded_design)
        model_trace.compute_log_prob()

        terms = -sum(guide_trace.nodes[l]["log_prob"] for l in target_labels)
        terms += sum(model_trace.nodes[l]["log_prob"] for l in target_labels)
        terms += sum(model_trace.nodes[l]["log_prob"] for l in observation_labels)
        terms = -terms.logsumexp(0) + math.log(M)

        # At eval time, add p(y | theta, d) terms
        if evaluation:
            trace.compute_log_prob()
            terms += sum(trace.nodes[l]["log_prob"] for l in observation_labels)

        return _safe_mean_terms(terms)

    return loss_fn


def neg_loss(loss):
    def new_loss(*args, **kwargs):
        return (-a for a in loss(*args, **kwargs))
    return new_loss


def opt_eig_loss_w_history(design, loss_fn, num_samples, num_steps, optim, time_budget):
    params = None
    est_loss_history = []
    xi_history = []
    baseline = 0.
    t = time.time()
    wall_times = []
    for step in range(num_steps):
        if params is not None:
            pyro.infer.util.zero_grads(params)
        with poutine.trace(param_only=True) as param_capture:
            agg_loss, loss = loss_fn(design, num_samples, evaluation=True, control_variate=baseline)
        baseline = -loss.detach()
        params = set(site["value"].unconstrained()
                     for site in param_capture.trace.nodes.values())
        if torch.isnan(agg_loss):
            raise ArithmeticError("Encountered NaN loss in opt_eig_ape_loss")
        agg_loss.backward(retain_graph=True)
        est_loss_history.append(loss.detach())
        wall_times.append(time.time() - t)
        optim(params)
        optim.step()
        print(pyro.param("xi")[0, 0, ...])
        print(step)
        print('eig', baseline.squeeze())
        if time_budget and time.time() - t > time_budget:
            break

    xi_history.append(pyro.param('xi').detach().clone())

    est_loss_history = torch.stack(est_loss_history)
    xi_history = torch.stack(xi_history)
    wall_times = torch.tensor(wall_times)

    return xi_history, est_loss_history, wall_times


# --------------------
# Start Pyro code implementation
num_steps = 1000
num_samples = 10
time_budget = 1000
seed = 420
num_parallel = 1
start_lr = 0.001
end_lr = 0.001
device = 'cpu'
n = 1
p = 1
scale = 1.

pyro.clear_param_store()
if seed >= 0:
    pyro.set_rng_seed(seed)
else:
    seed = int(torch.rand(tuple()) * 2 ** 30)
    pyro.set_rng_seed(seed)

xi_init = torch.randn((num_parallel, n, p), device=device)
# Change the prior distribution here
# prior params
w_prior_loc = torch.zeros(p, device=device)
w_prior_scale = scale * torch.ones(p, device=device)
sigma_prior_scale = scale * torch.tensor(1., device=device)

model_learn_xi = make_regression_model(
    w_prior_loc, w_prior_scale, sigma_prior_scale, xi_init)

contrastive_samples = num_samples

# Fix correct loss
targets = ["w", "sigma"]

guide = PosteriorGuide(n, p, (num_parallel,)).to(device)
eig_loss = _ace_eig_loss(model_learn_xi, guide, contrastive_samples, ["y"], targets)
loss = neg_loss(eig_loss)

# Train guide
print("Training")
# Look into switching this out with `opt_eig_loss_w_history`
# opt_eig_ape_loss(design, loss, num_samples=10, num_steps=20000, optim=optimizer)
gamma = (end_lr / start_lr) ** (1 / num_steps)
scheduler = pyro.optim.ExponentialLR({'optimizer': torch.optim.Adam, 'optim_args': {'lr': start_lr},
                                        'gamma': gamma})

design_prototype = torch.zeros(num_parallel, n, p, device=device)  # this is annoying, code needs refactor

xi_history, est_loss_history, wall_times = opt_eig_loss_w_history(
    design_prototype, loss, num_samples=num_samples, num_steps=num_steps, optim=scheduler,
    time_budget=time_budget)

est_eig_history = -est_loss_history

# Evaluate
print("Evaluation")
num_inner_samples = 2500
num_outer_samples = 100000
lower_loss = _ace_eig_loss(model_learn_xi, guide, num_inner_samples, "y", targets)  # isn't that an annoying API difference?
upper_loss = _vnmc_eig_loss(model_learn_xi, guide, "y", targets)
lower, upper = 0., 0.
max_samples = 10000
n_per_batch = max_samples // num_inner_samples
n_batches = num_inner_samples * num_outer_samples // max_samples
for i in range(n_batches):
    print(i)
    # lower += lower_loss(design, n_per_batch, evaluation=True)[1].detach().cpu()
    # upper += upper_loss(design, (n_per_batch, num_inner_samples), evaluation=True)[1].detach().cpu()
    lower += lower_loss(xi_history[-1], n_per_batch, evaluation=True)[1].detach().cpu()
    upper += upper_loss(xi_history[-1], (n_per_batch, num_inner_samples), evaluation=True)[1].detach().cpu()

final_upper_bound= upper.cpu() / n_batches
final_lower_bound = lower.cpu() / n_batches

print(final_lower_bound, final_upper_bound)

# Maybe add final/lower bounds?
results = {'seed': seed, 'xi_history': xi_history.cpu(), 'est_eig_history': est_eig_history.cpu(),
            'wall_times': wall_times.cpu()}
# Out:
# tensor([-1.6977], grad_fn=<SelectBackward0>)
# 0
# eig tensor(-0.2472)
# tensor([-1.6979], grad_fn=<SelectBackward0>)
# 1
# eig tensor(0.5802)
# tensor([-1.6981], grad_fn=<SelectBackward0>)
# 2
# eig tensor(0.1910)
# tensor([-1.6984], grad_fn=<SelectBackward0>)
# 3
# eig tensor(0.5558)
# tensor([-1.6987], grad_fn=<SelectBackward0>)
# 4
# eig tensor(-3.8025)
# tensor([-1.6989], grad_fn=<SelectBackward0>)
# 5
# eig tensor(0.4813)
# tensor([-1.6992], grad_fn=<SelectBackward0>)
# 6
# eig tensor(0.6277)
# tensor([-1.6994], grad_fn=<SelectBackward0>)
# 7
# eig tensor(-0.5476)
# tensor([-1.6996], grad_fn=<SelectBackward0>)
# 8
# eig tensor(-0.4766)
# tensor([-1.6997], grad_fn=<SelectBackward0>)
# 9
# eig tensor(-1.8593)
# tensor([-1.6999], grad_fn=<SelectBackward0>)
# 10
# eig tensor(-0.7433)
# tensor([-1.7000], grad_fn=<SelectBackward0>)
# 11
# eig tensor(0.6771)
# tensor([-1.7001], grad_fn=<SelectBackward0>)
# 12
# eig tensor(0.1910)
# tensor([-1.6998], grad_fn=<SelectBackward0>)
# 13
# eig tensor(-0.1653)
# tensor([-1.6995], grad_fn=<SelectBackward0>)
# 14
# eig tensor(1.2694)
# tensor([-1.6992], grad_fn=<SelectBackward0>)
# 15
# eig tensor(0.4525)
# tensor([-1.6990], grad_fn=<SelectBackward0>)
# 16
# eig tensor(0.8069)
# tensor([-1.6989], grad_fn=<SelectBackward0>)
# 17
# eig tensor(0.1702)
# tensor([-1.6986], grad_fn=<SelectBackward0>)
# 18
# eig tensor(-0.8706)
# tensor([-1.6984], grad_fn=<SelectBackward0>)
# 19
# eig tensor(0.5885)
# tensor([-1.6981], grad_fn=<SelectBackward0>)
# 20
# eig tensor(-0.2463)
# tensor([-1.6979], grad_fn=<SelectBackward0>)
# 21
# eig tensor(0.8127)
# tensor([-1.6978], grad_fn=<SelectBackward0>)
# 22
# eig tensor(-1.2300)
# tensor([-1.6976], grad_fn=<SelectBackward0>)
# 23
# eig tensor(0.6893)
# tensor([-1.6975], grad_fn=<SelectBackward0>)
# 24
# eig tensor(0.7486)
# tensor([-1.6973], grad_fn=<SelectBackward0>)
# 25
# eig tensor(0.6047)
# tensor([-1.6972], grad_fn=<SelectBackward0>)
# 26
# eig tensor(0.3642)
# tensor([-1.6972], grad_fn=<SelectBackward0>)
# 27
# eig tensor(0.3632)
# tensor([-1.6972], grad_fn=<SelectBackward0>)
# 28
# eig tensor(-0.6518)
# tensor([-1.6971], grad_fn=<SelectBackward0>)
# 29
# eig tensor(0.2480)
# tensor([-1.6971], grad_fn=<SelectBackward0>)
# 30
# eig tensor(-0.2751)
# tensor([-1.6971], grad_fn=<SelectBackward0>)
# 31
# eig tensor(0.9924)
# tensor([-1.6971], grad_fn=<SelectBackward0>)
# 32
# eig tensor(0.7584)
# tensor([-1.6966], grad_fn=<SelectBackward0>)
# 33
# eig tensor(0.5613)
# tensor([-1.6961], grad_fn=<SelectBackward0>)
# 34
# eig tensor(1.0597)
# tensor([-1.6957], grad_fn=<SelectBackward0>)
# 35
# eig tensor(0.8046)
# tensor([-1.6953], grad_fn=<SelectBackward0>)
# 36
# eig tensor(-1.2293)
# tensor([-1.6949], grad_fn=<SelectBackward0>)
# 37
# eig tensor(0.7334)
# tensor([-1.6946], grad_fn=<SelectBackward0>)
# 38
# eig tensor(1.0290)
# tensor([-1.6943], grad_fn=<SelectBackward0>)
# 39
# eig tensor(-0.0419)
# tensor([-1.6940], grad_fn=<SelectBackward0>)
# 40
# eig tensor(0.8395)
# tensor([-1.6937], grad_fn=<SelectBackward0>)
# 41
# eig tensor(1.1948)
# tensor([-1.6935], grad_fn=<SelectBackward0>)
# 42
# eig tensor(0.3947)
# tensor([-1.6933], grad_fn=<SelectBackward0>)
# 43
# eig tensor(1.1658)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 44
# eig tensor(0.5931)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 45
# eig tensor(0.3888)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 46
# eig tensor(0.3309)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 47
# eig tensor(0.4160)
# tensor([-1.6928], grad_fn=<SelectBackward0>)
# 48
# eig tensor(1.3168)
# tensor([-1.6927], grad_fn=<SelectBackward0>)
# 49
# eig tensor(1.1735)
# tensor([-1.6927], grad_fn=<SelectBackward0>)
# 50
# eig tensor(0.3655)
# tensor([-1.6926], grad_fn=<SelectBackward0>)
# 51
# eig tensor(0.8871)
# tensor([-1.6926], grad_fn=<SelectBackward0>)
# 52
# eig tensor(0.5799)
# tensor([-1.6926], grad_fn=<SelectBackward0>)
# 53
# eig tensor(0.3443)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 54
# eig tensor(0.7521)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 55
# eig tensor(0.0185)
# tensor([-1.6923], grad_fn=<SelectBackward0>)
# 56
# eig tensor(0.6039)
# tensor([-1.6922], grad_fn=<SelectBackward0>)
# 57
# eig tensor(1.1682)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 58
# eig tensor(1.1237)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 59
# eig tensor(0.9987)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 60
# eig tensor(0.8180)
# tensor([-1.6919], grad_fn=<SelectBackward0>)
# 61
# eig tensor(0.8682)
# tensor([-1.6918], grad_fn=<SelectBackward0>)
# 62
# eig tensor(0.5870)
# tensor([-1.6918], grad_fn=<SelectBackward0>)
# 63
# eig tensor(0.5922)
# tensor([-1.6917], grad_fn=<SelectBackward0>)
# 64
# eig tensor(1.0147)
# tensor([-1.6917], grad_fn=<SelectBackward0>)
# 65
# eig tensor(0.6265)
# tensor([-1.6918], grad_fn=<SelectBackward0>)
# 66
# eig tensor(1.1453)
# tensor([-1.6919], grad_fn=<SelectBackward0>)
# 67
# eig tensor(1.1992)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 68
# eig tensor(0.5474)
# tensor([-1.6922], grad_fn=<SelectBackward0>)
# 69
# eig tensor(1.0577)
# tensor([-1.6923], grad_fn=<SelectBackward0>)
# 70
# eig tensor(0.8441)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 71
# eig tensor(1.0580)
# tensor([-1.6926], grad_fn=<SelectBackward0>)
# 72
# eig tensor(0.8232)
# tensor([-1.6926], grad_fn=<SelectBackward0>)
# 73
# eig tensor(0.9559)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 74
# eig tensor(1.0573)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 75
# eig tensor(0.7794)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 76
# eig tensor(0.9625)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 77
# eig tensor(1.3685)
# tensor([-1.6926], grad_fn=<SelectBackward0>)
# 78
# eig tensor(0.8662)
# tensor([-1.6927], grad_fn=<SelectBackward0>)
# 79
# eig tensor(1.0118)
# tensor([-1.6927], grad_fn=<SelectBackward0>)
# 80
# eig tensor(1.2967)
# tensor([-1.6927], grad_fn=<SelectBackward0>)
# 81
# eig tensor(1.3150)
# tensor([-1.6927], grad_fn=<SelectBackward0>)
# 82
# eig tensor(0.8399)
# tensor([-1.6928], grad_fn=<SelectBackward0>)
# 83
# eig tensor(0.3403)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 84
# eig tensor(0.7590)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 85
# eig tensor(0.3731)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 86
# eig tensor(0.9836)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 87
# eig tensor(1.7930)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 88
# eig tensor(0.8244)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 89
# eig tensor(1.4407)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 90
# eig tensor(0.7851)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 91
# eig tensor(0.8985)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 92
# eig tensor(1.5018)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 93
# eig tensor(0.9263)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 94
# eig tensor(1.2043)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 95
# eig tensor(0.7927)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 96
# eig tensor(0.6772)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 97
# eig tensor(1.2567)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 98
# eig tensor(1.1706)
# tensor([-1.6933], grad_fn=<SelectBackward0>)
# 99
# eig tensor(0.7243)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 100
# eig tensor(0.7777)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 101
# eig tensor(1.2406)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 102
# eig tensor(1.0881)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 103
# eig tensor(1.1397)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 104
# eig tensor(0.4583)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 105
# eig tensor(1.5199)
# tensor([-1.6928], grad_fn=<SelectBackward0>)
# 106
# eig tensor(1.4451)
# tensor([-1.6922], grad_fn=<SelectBackward0>)
# 107
# eig tensor(0.8630)
# tensor([-1.6917], grad_fn=<SelectBackward0>)
# 108
# eig tensor(1.3131)
# tensor([-1.6911], grad_fn=<SelectBackward0>)
# 109
# eig tensor(1.0312)
# tensor([-1.6906], grad_fn=<SelectBackward0>)
# 110
# eig tensor(0.9132)
# tensor([-1.6901], grad_fn=<SelectBackward0>)
# 111
# eig tensor(0.7866)
# tensor([-1.6896], grad_fn=<SelectBackward0>)
# 112
# eig tensor(1.4796)
# tensor([-1.6893], grad_fn=<SelectBackward0>)
# 113
# eig tensor(1.3060)
# tensor([-1.6890], grad_fn=<SelectBackward0>)
# 114
# eig tensor(1.4858)
# tensor([-1.6887], grad_fn=<SelectBackward0>)
# 115
# eig tensor(1.4751)
# tensor([-1.6885], grad_fn=<SelectBackward0>)
# 116
# eig tensor(0.8602)
# tensor([-1.6882], grad_fn=<SelectBackward0>)
# 117
# eig tensor(0.9835)
# tensor([-1.6880], grad_fn=<SelectBackward0>)
# 118
# eig tensor(1.4462)
# tensor([-1.6878], grad_fn=<SelectBackward0>)
# 119
# eig tensor(0.7272)
# tensor([-1.6876], grad_fn=<SelectBackward0>)
# 120
# eig tensor(1.2302)
# tensor([-1.6874], grad_fn=<SelectBackward0>)
# 121
# eig tensor(1.3430)
# tensor([-1.6872], grad_fn=<SelectBackward0>)
# 122
# eig tensor(0.7169)
# tensor([-1.6871], grad_fn=<SelectBackward0>)
# 123
# eig tensor(1.0926)
# tensor([-1.6868], grad_fn=<SelectBackward0>)
# 124
# eig tensor(0.6020)
# tensor([-1.6865], grad_fn=<SelectBackward0>)
# 125
# eig tensor(1.0664)
# tensor([-1.6862], grad_fn=<SelectBackward0>)
# 126
# eig tensor(0.9322)
# tensor([-1.6859], grad_fn=<SelectBackward0>)
# 127
# eig tensor(0.5537)
# tensor([-1.6856], grad_fn=<SelectBackward0>)
# 128
# eig tensor(1.2732)
# tensor([-1.6854], grad_fn=<SelectBackward0>)
# 129
# eig tensor(0.5015)
# tensor([-1.6854], grad_fn=<SelectBackward0>)
# 130
# eig tensor(1.0541)
# tensor([-1.6853], grad_fn=<SelectBackward0>)
# 131
# eig tensor(0.8493)
# tensor([-1.6852], grad_fn=<SelectBackward0>)
# 132
# eig tensor(0.7264)
# tensor([-1.6850], grad_fn=<SelectBackward0>)
# 133
# eig tensor(1.1401)
# tensor([-1.6849], grad_fn=<SelectBackward0>)
# 134
# eig tensor(1.0863)
# tensor([-1.6844], grad_fn=<SelectBackward0>)
# 135
# eig tensor(0.6619)
# tensor([-1.6841], grad_fn=<SelectBackward0>)
# 136
# eig tensor(0.9233)
# tensor([-1.6837], grad_fn=<SelectBackward0>)
# 137
# eig tensor(1.6995)
# tensor([-1.6834], grad_fn=<SelectBackward0>)
# 138
# eig tensor(0.8750)
# tensor([-1.6831], grad_fn=<SelectBackward0>)
# 139
# eig tensor(1.1541)
# tensor([-1.6828], grad_fn=<SelectBackward0>)
# 140
# eig tensor(0.7451)
# tensor([-1.6825], grad_fn=<SelectBackward0>)
# 141
# eig tensor(1.2794)
# tensor([-1.6822], grad_fn=<SelectBackward0>)
# 142
# eig tensor(1.2960)
# tensor([-1.6820], grad_fn=<SelectBackward0>)
# 143
# eig tensor(1.2425)
# tensor([-1.6818], grad_fn=<SelectBackward0>)
# 144
# eig tensor(1.1042)
# tensor([-1.6816], grad_fn=<SelectBackward0>)
# 145
# eig tensor(0.8588)
# tensor([-1.6814], grad_fn=<SelectBackward0>)
# 146
# eig tensor(1.3568)
# tensor([-1.6813], grad_fn=<SelectBackward0>)
# 147
# eig tensor(1.0237)
# tensor([-1.6811], grad_fn=<SelectBackward0>)
# 148
# eig tensor(0.7276)
# tensor([-1.6810], grad_fn=<SelectBackward0>)
# 149
# eig tensor(0.8416)
# tensor([-1.6809], grad_fn=<SelectBackward0>)
# 150
# eig tensor(0.7935)
# tensor([-1.6808], grad_fn=<SelectBackward0>)
# 151
# eig tensor(0.9000)
# tensor([-1.6806], grad_fn=<SelectBackward0>)
# 152
# eig tensor(1.3856)
# tensor([-1.6804], grad_fn=<SelectBackward0>)
# 153
# eig tensor(0.9295)
# tensor([-1.6803], grad_fn=<SelectBackward0>)
# 154
# eig tensor(1.0463)
# tensor([-1.6801], grad_fn=<SelectBackward0>)
# 155
# eig tensor(1.9846)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 156
# eig tensor(1.3416)
# tensor([-1.6798], grad_fn=<SelectBackward0>)
# 157
# eig tensor(1.5273)
# tensor([-1.6796], grad_fn=<SelectBackward0>)
# 158
# eig tensor(1.5933)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 159
# eig tensor(1.1161)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 160
# eig tensor(0.8260)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 161
# eig tensor(1.3108)
# tensor([-1.6788], grad_fn=<SelectBackward0>)
# 162
# eig tensor(0.5934)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 163
# eig tensor(1.1902)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 164
# eig tensor(0.9173)
# tensor([-1.6781], grad_fn=<SelectBackward0>)
# 165
# eig tensor(0.9877)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 166
# eig tensor(0.6731)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 167
# eig tensor(1.1051)
# tensor([-1.6776], grad_fn=<SelectBackward0>)
# 168
# eig tensor(0.7947)
# tensor([-1.6776], grad_fn=<SelectBackward0>)
# 169
# eig tensor(1.7882)
# tensor([-1.6775], grad_fn=<SelectBackward0>)
# 170
# eig tensor(1.0405)
# tensor([-1.6774], grad_fn=<SelectBackward0>)
# 171
# eig tensor(1.0708)
# tensor([-1.6774], grad_fn=<SelectBackward0>)
# 172
# eig tensor(1.4025)
# tensor([-1.6773], grad_fn=<SelectBackward0>)
# 173
# eig tensor(1.1818)
# tensor([-1.6773], grad_fn=<SelectBackward0>)
# 174
# eig tensor(1.3812)
# tensor([-1.6773], grad_fn=<SelectBackward0>)
# 175
# eig tensor(0.7486)
# tensor([-1.6772], grad_fn=<SelectBackward0>)
# 176
# eig tensor(0.9039)
# tensor([-1.6772], grad_fn=<SelectBackward0>)
# 177
# eig tensor(1.0966)
# tensor([-1.6771], grad_fn=<SelectBackward0>)
# 178
# eig tensor(1.0344)
# tensor([-1.6771], grad_fn=<SelectBackward0>)
# 179
# eig tensor(1.1920)
# tensor([-1.6770], grad_fn=<SelectBackward0>)
# 180
# eig tensor(1.4901)
# tensor([-1.6769], grad_fn=<SelectBackward0>)
# 181
# eig tensor(0.6551)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 182
# eig tensor(0.9087)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 183
# eig tensor(1.0549)
# tensor([-1.6770], grad_fn=<SelectBackward0>)
# 184
# eig tensor(0.5776)
# tensor([-1.6773], grad_fn=<SelectBackward0>)
# 185
# eig tensor(0.9787)
# tensor([-1.6775], grad_fn=<SelectBackward0>)
# 186
# eig tensor(1.0248)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 187
# eig tensor(1.3094)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 188
# eig tensor(1.4719)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 189
# eig tensor(1.5741)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 190
# eig tensor(1.0687)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 191
# eig tensor(1.0276)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 192
# eig tensor(0.4261)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 193
# eig tensor(1.7111)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 194
# eig tensor(1.1023)
# tensor([-1.6788], grad_fn=<SelectBackward0>)
# 195
# eig tensor(0.3776)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 196
# eig tensor(1.3377)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 197
# eig tensor(1.2239)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 198
# eig tensor(1.2261)
# tensor([-1.6793], grad_fn=<SelectBackward0>)
# 199
# eig tensor(0.4187)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 200
# eig tensor(0.8282)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 201
# eig tensor(0.6890)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 202
# eig tensor(0.9802)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 203
# eig tensor(0.5980)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 204
# eig tensor(0.8015)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 205
# eig tensor(0.9209)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 206
# eig tensor(0.8977)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 207
# eig tensor(1.0293)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 208
# eig tensor(1.0203)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 209
# eig tensor(1.3157)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 210
# eig tensor(0.8994)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 211
# eig tensor(0.9282)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 212
# eig tensor(1.7821)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 213
# eig tensor(1.0414)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 214
# eig tensor(0.7038)
# tensor([-1.6796], grad_fn=<SelectBackward0>)
# 215
# eig tensor(1.1139)
# tensor([-1.6797], grad_fn=<SelectBackward0>)
# 216
# eig tensor(1.1977)
# tensor([-1.6798], grad_fn=<SelectBackward0>)
# 217
# eig tensor(1.0823)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 218
# eig tensor(1.2378)
# tensor([-1.6800], grad_fn=<SelectBackward0>)
# 219
# eig tensor(1.0135)
# tensor([-1.6800], grad_fn=<SelectBackward0>)
# 220
# eig tensor(1.2080)
# tensor([-1.6801], grad_fn=<SelectBackward0>)
# 221
# eig tensor(1.0845)
# tensor([-1.6802], grad_fn=<SelectBackward0>)
# 222
# eig tensor(-0.1457)
# tensor([-1.6802], grad_fn=<SelectBackward0>)
# 223
# eig tensor(1.2953)
# tensor([-1.6802], grad_fn=<SelectBackward0>)
# 224
# eig tensor(1.2295)
# tensor([-1.6802], grad_fn=<SelectBackward0>)
# 225
# eig tensor(0.9087)
# tensor([-1.6802], grad_fn=<SelectBackward0>)
# 226
# eig tensor(1.0355)
# tensor([-1.6803], grad_fn=<SelectBackward0>)
# 227
# eig tensor(0.8318)
# tensor([-1.6804], grad_fn=<SelectBackward0>)
# 228
# eig tensor(0.8116)
# tensor([-1.6803], grad_fn=<SelectBackward0>)
# 229
# eig tensor(0.9809)
# tensor([-1.6802], grad_fn=<SelectBackward0>)
# 230
# eig tensor(1.0267)
# tensor([-1.6802], grad_fn=<SelectBackward0>)
# 231
# eig tensor(1.0700)
# tensor([-1.6800], grad_fn=<SelectBackward0>)
# 232
# eig tensor(0.6834)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 233
# eig tensor(0.7838)
# tensor([-1.6797], grad_fn=<SelectBackward0>)
# 234
# eig tensor(0.8451)
# tensor([-1.6796], grad_fn=<SelectBackward0>)
# 235
# eig tensor(1.1646)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 236
# eig tensor(1.2166)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 237
# eig tensor(0.8783)
# tensor([-1.6793], grad_fn=<SelectBackward0>)
# 238
# eig tensor(0.5009)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 239
# eig tensor(1.3117)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 240
# eig tensor(1.4572)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 241
# eig tensor(0.9317)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 242
# eig tensor(1.1059)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 243
# eig tensor(0.3806)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 244
# eig tensor(1.1444)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 245
# eig tensor(0.9420)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 246
# eig tensor(0.7265)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 247
# eig tensor(1.3373)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 248
# eig tensor(0.6559)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 249
# eig tensor(1.8694)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 250
# eig tensor(0.8916)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 251
# eig tensor(0.8638)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 252
# eig tensor(0.2813)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 253
# eig tensor(0.6871)
# tensor([-1.6793], grad_fn=<SelectBackward0>)
# 254
# eig tensor(1.0947)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 255
# eig tensor(1.5723)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 256
# eig tensor(0.5794)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 257
# eig tensor(0.7040)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 258
# eig tensor(1.2144)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 259
# eig tensor(1.3903)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 260
# eig tensor(0.0400)
# tensor([-1.6772], grad_fn=<SelectBackward0>)
# 261
# eig tensor(1.0227)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 262
# eig tensor(1.2790)
# tensor([-1.6764], grad_fn=<SelectBackward0>)
# 263
# eig tensor(1.2025)
# tensor([-1.6761], grad_fn=<SelectBackward0>)
# 264
# eig tensor(1.1015)
# tensor([-1.6758], grad_fn=<SelectBackward0>)
# 265
# eig tensor(1.7436)
# tensor([-1.6755], grad_fn=<SelectBackward0>)
# 266
# eig tensor(1.5048)
# tensor([-1.6753], grad_fn=<SelectBackward0>)
# 267
# eig tensor(1.0695)
# tensor([-1.6750], grad_fn=<SelectBackward0>)
# 268
# eig tensor(0.3245)
# tensor([-1.6747], grad_fn=<SelectBackward0>)
# 269
# eig tensor(0.9398)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 270
# eig tensor(1.2665)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 271
# eig tensor(1.1107)
# tensor([-1.6742], grad_fn=<SelectBackward0>)
# 272
# eig tensor(1.7622)
# tensor([-1.6740], grad_fn=<SelectBackward0>)
# 273
# eig tensor(0.9901)
# tensor([-1.6739], grad_fn=<SelectBackward0>)
# 274
# eig tensor(0.9042)
# tensor([-1.6737], grad_fn=<SelectBackward0>)
# 275
# eig tensor(0.8528)
# tensor([-1.6737], grad_fn=<SelectBackward0>)
# 276
# eig tensor(1.2948)
# tensor([-1.6730], grad_fn=<SelectBackward0>)
# 277
# eig tensor(0.7957)
# tensor([-1.6724], grad_fn=<SelectBackward0>)
# 278
# eig tensor(1.2807)
# tensor([-1.6718], grad_fn=<SelectBackward0>)
# 279
# eig tensor(1.1209)
# tensor([-1.6716], grad_fn=<SelectBackward0>)
# 280
# eig tensor(0.9167)
# tensor([-1.6715], grad_fn=<SelectBackward0>)
# 281
# eig tensor(0.8122)
# tensor([-1.6713], grad_fn=<SelectBackward0>)
# 282
# eig tensor(0.5778)
# tensor([-1.6712], grad_fn=<SelectBackward0>)
# 283
# eig tensor(2.0290)
# tensor([-1.6707], grad_fn=<SelectBackward0>)
# 284
# eig tensor(0.6457)
# tensor([-1.6704], grad_fn=<SelectBackward0>)
# 285
# eig tensor(0.3350)
# tensor([-1.6700], grad_fn=<SelectBackward0>)
# 286
# eig tensor(1.1589)
# tensor([-1.6698], grad_fn=<SelectBackward0>)
# 287
# eig tensor(1.2932)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 288
# eig tensor(0.6332)
# tensor([-1.6693], grad_fn=<SelectBackward0>)
# 289
# eig tensor(0.8082)
# tensor([-1.6691], grad_fn=<SelectBackward0>)
# 290
# eig tensor(0.9979)
# tensor([-1.6689], grad_fn=<SelectBackward0>)
# 291
# eig tensor(0.9248)
# tensor([-1.6687], grad_fn=<SelectBackward0>)
# 292
# eig tensor(1.1920)
# tensor([-1.6686], grad_fn=<SelectBackward0>)
# 293
# eig tensor(1.3167)
# tensor([-1.6685], grad_fn=<SelectBackward0>)
# 294
# eig tensor(0.7365)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 295
# eig tensor(1.0465)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 296
# eig tensor(1.2474)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 297
# eig tensor(1.2300)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 298
# eig tensor(0.4179)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 299
# eig tensor(1.1702)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 300
# eig tensor(1.1338)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 301
# eig tensor(1.1992)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 302
# eig tensor(0.8168)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 303
# eig tensor(1.0301)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 304
# eig tensor(1.2728)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 305
# eig tensor(0.5998)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 306
# eig tensor(0.5763)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 307
# eig tensor(0.9785)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 308
# eig tensor(0.7528)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 309
# eig tensor(1.2293)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 310
# eig tensor(0.5690)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 311
# eig tensor(0.8060)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 312
# eig tensor(0.9801)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 313
# eig tensor(1.4164)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 314
# eig tensor(0.8917)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 315
# eig tensor(1.4621)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 316
# eig tensor(1.2510)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 317
# eig tensor(0.8972)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 318
# eig tensor(0.8962)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 319
# eig tensor(1.1819)
# tensor([-1.6682], grad_fn=<SelectBackward0>)
# 320
# eig tensor(0.8829)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 321
# eig tensor(1.0845)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 322
# eig tensor(0.8274)
# tensor([-1.6684], grad_fn=<SelectBackward0>)
# 323
# eig tensor(0.9351)
# tensor([-1.6685], grad_fn=<SelectBackward0>)
# 324
# eig tensor(0.6487)
# tensor([-1.6686], grad_fn=<SelectBackward0>)
# 325
# eig tensor(0.8872)
# tensor([-1.6686], grad_fn=<SelectBackward0>)
# 326
# eig tensor(0.7850)
# tensor([-1.6687], grad_fn=<SelectBackward0>)
# 327
# eig tensor(0.7942)
# tensor([-1.6687], grad_fn=<SelectBackward0>)
# 328
# eig tensor(0.4277)
# tensor([-1.6688], grad_fn=<SelectBackward0>)
# 329
# eig tensor(1.0836)
# tensor([-1.6688], grad_fn=<SelectBackward0>)
# 330
# eig tensor(0.4800)
# tensor([-1.6689], grad_fn=<SelectBackward0>)
# 331
# eig tensor(0.9286)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 332
# eig tensor(1.7419)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 333
# eig tensor(1.0696)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 334
# eig tensor(1.3984)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 335
# eig tensor(0.2864)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 336
# eig tensor(1.4933)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 337
# eig tensor(0.7926)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 338
# eig tensor(0.9283)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 339
# eig tensor(0.6256)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 340
# eig tensor(1.9578)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 341
# eig tensor(1.3202)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 342
# eig tensor(0.5241)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 343
# eig tensor(1.1615)
# tensor([-1.6691], grad_fn=<SelectBackward0>)
# 344
# eig tensor(1.0518)
# tensor([-1.6692], grad_fn=<SelectBackward0>)
# 345
# eig tensor(0.8031)
# tensor([-1.6692], grad_fn=<SelectBackward0>)
# 346
# eig tensor(0.6458)
# tensor([-1.6693], grad_fn=<SelectBackward0>)
# 347
# eig tensor(1.0974)
# tensor([-1.6694], grad_fn=<SelectBackward0>)
# 348
# eig tensor(1.2092)
# tensor([-1.6694], grad_fn=<SelectBackward0>)
# 349
# eig tensor(1.2056)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 350
# eig tensor(1.0505)
# tensor([-1.6696], grad_fn=<SelectBackward0>)
# 351
# eig tensor(0.4900)
# tensor([-1.6696], grad_fn=<SelectBackward0>)
# 352
# eig tensor(1.1451)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 353
# eig tensor(0.4878)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 354
# eig tensor(0.8926)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 355
# eig tensor(1.0902)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 356
# eig tensor(1.0578)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 357
# eig tensor(1.7036)
# tensor([-1.6695], grad_fn=<SelectBackward0>)
# 358
# eig tensor(0.8097)
# tensor([-1.6691], grad_fn=<SelectBackward0>)
# 359
# eig tensor(1.4298)
# tensor([-1.6688], grad_fn=<SelectBackward0>)
# 360
# eig tensor(1.0441)
# tensor([-1.6685], grad_fn=<SelectBackward0>)
# 361
# eig tensor(1.0496)
# tensor([-1.6682], grad_fn=<SelectBackward0>)
# 362
# eig tensor(1.3188)
# tensor([-1.6679], grad_fn=<SelectBackward0>)
# 363
# eig tensor(0.9201)
# tensor([-1.6677], grad_fn=<SelectBackward0>)
# 364
# eig tensor(0.9647)
# tensor([-1.6676], grad_fn=<SelectBackward0>)
# 365
# eig tensor(0.8792)
# tensor([-1.6675], grad_fn=<SelectBackward0>)
# 366
# eig tensor(1.2034)
# tensor([-1.6673], grad_fn=<SelectBackward0>)
# 367
# eig tensor(1.2151)
# tensor([-1.6673], grad_fn=<SelectBackward0>)
# 368
# eig tensor(0.9819)
# tensor([-1.6672], grad_fn=<SelectBackward0>)
# 369
# eig tensor(0.9730)
# tensor([-1.6672], grad_fn=<SelectBackward0>)
# 370
# eig tensor(0.4012)
# tensor([-1.6672], grad_fn=<SelectBackward0>)
# 371
# eig tensor(0.8398)
# tensor([-1.6671], grad_fn=<SelectBackward0>)
# 372
# eig tensor(1.3104)
# tensor([-1.6671], grad_fn=<SelectBackward0>)
# 373
# eig tensor(1.3776)
# tensor([-1.6671], grad_fn=<SelectBackward0>)
# 374
# eig tensor(0.9732)
# tensor([-1.6670], grad_fn=<SelectBackward0>)
# 375
# eig tensor(0.5689)
# tensor([-1.6670], grad_fn=<SelectBackward0>)
# 376
# eig tensor(1.1880)
# tensor([-1.6669], grad_fn=<SelectBackward0>)
# 377
# eig tensor(1.3189)
# tensor([-1.6669], grad_fn=<SelectBackward0>)
# 378
# eig tensor(0.9755)
# tensor([-1.6669], grad_fn=<SelectBackward0>)
# 379
# eig tensor(0.5725)
# tensor([-1.6668], grad_fn=<SelectBackward0>)
# 380
# eig tensor(1.3463)
# tensor([-1.6667], grad_fn=<SelectBackward0>)
# 381
# eig tensor(0.7332)
# tensor([-1.6666], grad_fn=<SelectBackward0>)
# 382
# eig tensor(0.3256)
# tensor([-1.6665], grad_fn=<SelectBackward0>)
# 383
# eig tensor(1.0460)
# tensor([-1.6664], grad_fn=<SelectBackward0>)
# 384
# eig tensor(1.4961)
# tensor([-1.6663], grad_fn=<SelectBackward0>)
# 385
# eig tensor(1.0122)
# tensor([-1.6662], grad_fn=<SelectBackward0>)
# 386
# eig tensor(0.8083)
# tensor([-1.6661], grad_fn=<SelectBackward0>)
# 387
# eig tensor(1.3228)
# tensor([-1.6660], grad_fn=<SelectBackward0>)
# 388
# eig tensor(0.2761)
# tensor([-1.6660], grad_fn=<SelectBackward0>)
# 389
# eig tensor(1.2841)
# tensor([-1.6659], grad_fn=<SelectBackward0>)
# 390
# eig tensor(0.9353)
# tensor([-1.6658], grad_fn=<SelectBackward0>)
# 391
# eig tensor(0.6862)
# tensor([-1.6657], grad_fn=<SelectBackward0>)
# 392
# eig tensor(0.6966)
# tensor([-1.6656], grad_fn=<SelectBackward0>)
# 393
# eig tensor(0.7260)
# tensor([-1.6655], grad_fn=<SelectBackward0>)
# 394
# eig tensor(1.2497)
# tensor([-1.6657], grad_fn=<SelectBackward0>)
# 395
# eig tensor(1.8101)
# tensor([-1.6658], grad_fn=<SelectBackward0>)
# 396
# eig tensor(1.5948)
# tensor([-1.6660], grad_fn=<SelectBackward0>)
# 397
# eig tensor(0.5615)
# tensor([-1.6663], grad_fn=<SelectBackward0>)
# 398
# eig tensor(1.3361)
# tensor([-1.6665], grad_fn=<SelectBackward0>)
# 399
# eig tensor(1.8892)
# tensor([-1.6666], grad_fn=<SelectBackward0>)
# 400
# eig tensor(0.6218)
# tensor([-1.6668], grad_fn=<SelectBackward0>)
# 401
# eig tensor(1.3218)
# tensor([-1.6669], grad_fn=<SelectBackward0>)
# 402
# eig tensor(1.3967)
# tensor([-1.6671], grad_fn=<SelectBackward0>)
# 403
# eig tensor(0.8530)
# tensor([-1.6672], grad_fn=<SelectBackward0>)
# 404
# eig tensor(1.1747)
# tensor([-1.6673], grad_fn=<SelectBackward0>)
# 405
# eig tensor(1.2487)
# tensor([-1.6674], grad_fn=<SelectBackward0>)
# 406
# eig tensor(1.0893)
# tensor([-1.6676], grad_fn=<SelectBackward0>)
# 407
# eig tensor(2.0110)
# tensor([-1.6678], grad_fn=<SelectBackward0>)
# 408
# eig tensor(1.0695)
# tensor([-1.6680], grad_fn=<SelectBackward0>)
# 409
# eig tensor(0.9355)
# tensor([-1.6683], grad_fn=<SelectBackward0>)
# 410
# eig tensor(0.7312)
# tensor([-1.6685], grad_fn=<SelectBackward0>)
# 411
# eig tensor(0.0069)
# tensor([-1.6686], grad_fn=<SelectBackward0>)
# 412
# eig tensor(0.9629)
# tensor([-1.6688], grad_fn=<SelectBackward0>)
# 413
# eig tensor(1.0883)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 414
# eig tensor(0.2018)
# tensor([-1.6692], grad_fn=<SelectBackward0>)
# 415
# eig tensor(0.7808)
# tensor([-1.6693], grad_fn=<SelectBackward0>)
# 416
# eig tensor(1.1155)
# tensor([-1.6693], grad_fn=<SelectBackward0>)
# 417
# eig tensor(1.4164)
# tensor([-1.6694], grad_fn=<SelectBackward0>)
# 418
# eig tensor(0.5271)
# tensor([-1.6694], grad_fn=<SelectBackward0>)
# 419
# eig tensor(1.0000)
# tensor([-1.6694], grad_fn=<SelectBackward0>)
# 420
# eig tensor(0.8582)
# tensor([-1.6694], grad_fn=<SelectBackward0>)
# 421
# eig tensor(1.3594)
# tensor([-1.6693], grad_fn=<SelectBackward0>)
# 422
# eig tensor(1.1826)
# tensor([-1.6692], grad_fn=<SelectBackward0>)
# 423
# eig tensor(1.5226)
# tensor([-1.6692], grad_fn=<SelectBackward0>)
# 424
# eig tensor(0.9259)
# tensor([-1.6691], grad_fn=<SelectBackward0>)
# 425
# eig tensor(1.2935)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 426
# eig tensor(1.3712)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 427
# eig tensor(1.0162)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 428
# eig tensor(1.5154)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 429
# eig tensor(1.2742)
# tensor([-1.6690], grad_fn=<SelectBackward0>)
# 430
# eig tensor(1.2013)
# tensor([-1.6691], grad_fn=<SelectBackward0>)
# 431
# eig tensor(1.4613)
# tensor([-1.6691], grad_fn=<SelectBackward0>)
# 432
# eig tensor(1.1722)
# tensor([-1.6705], grad_fn=<SelectBackward0>)
# 433
# eig tensor(0.8648)
# tensor([-1.6717], grad_fn=<SelectBackward0>)
# 434
# eig tensor(1.2747)
# tensor([-1.6728], grad_fn=<SelectBackward0>)
# 435
# eig tensor(1.1475)
# tensor([-1.6738], grad_fn=<SelectBackward0>)
# 436
# eig tensor(0.8490)
# tensor([-1.6746], grad_fn=<SelectBackward0>)
# 437
# eig tensor(1.3096)
# tensor([-1.6754], grad_fn=<SelectBackward0>)
# 438
# eig tensor(0.7615)
# tensor([-1.6760], grad_fn=<SelectBackward0>)
# 439
# eig tensor(1.3367)
# tensor([-1.6766], grad_fn=<SelectBackward0>)
# 440
# eig tensor(0.8704)
# tensor([-1.6772], grad_fn=<SelectBackward0>)
# 441
# eig tensor(1.2649)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 442
# eig tensor(0.8984)
# tensor([-1.6781], grad_fn=<SelectBackward0>)
# 443
# eig tensor(0.2044)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 444
# eig tensor(0.9185)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 445
# eig tensor(1.6605)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 446
# eig tensor(0.7797)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 447
# eig tensor(0.9883)
# tensor([-1.6775], grad_fn=<SelectBackward0>)
# 448
# eig tensor(1.0094)
# tensor([-1.6774], grad_fn=<SelectBackward0>)
# 449
# eig tensor(1.1719)
# tensor([-1.6773], grad_fn=<SelectBackward0>)
# 450
# eig tensor(1.0678)
# tensor([-1.6771], grad_fn=<SelectBackward0>)
# 451
# eig tensor(1.1516)
# tensor([-1.6770], grad_fn=<SelectBackward0>)
# 452
# eig tensor(1.2573)
# tensor([-1.6770], grad_fn=<SelectBackward0>)
# 453
# eig tensor(1.0098)
# tensor([-1.6769], grad_fn=<SelectBackward0>)
# 454
# eig tensor(1.0511)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 455
# eig tensor(0.8521)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 456
# eig tensor(0.7014)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 457
# eig tensor(2.1768)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 458
# eig tensor(1.0579)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 459
# eig tensor(0.9191)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 460
# eig tensor(0.8125)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 461
# eig tensor(1.2686)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 462
# eig tensor(1.0952)
# tensor([-1.6766], grad_fn=<SelectBackward0>)
# 463
# eig tensor(0.7228)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 464
# eig tensor(1.4253)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 465
# eig tensor(0.5660)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 466
# eig tensor(0.6672)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 467
# eig tensor(0.8264)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 468
# eig tensor(1.1226)
# tensor([-1.6769], grad_fn=<SelectBackward0>)
# 469
# eig tensor(0.7598)
# tensor([-1.6769], grad_fn=<SelectBackward0>)
# 470
# eig tensor(0.9961)
# tensor([-1.6769], grad_fn=<SelectBackward0>)
# 471
# eig tensor(0.9044)
# tensor([-1.6770], grad_fn=<SelectBackward0>)
# 472
# eig tensor(1.1432)
# tensor([-1.6771], grad_fn=<SelectBackward0>)
# 473
# eig tensor(1.0297)
# tensor([-1.6772], grad_fn=<SelectBackward0>)
# 474
# eig tensor(0.7538)
# tensor([-1.6773], grad_fn=<SelectBackward0>)
# 475
# eig tensor(1.1960)
# tensor([-1.6774], grad_fn=<SelectBackward0>)
# 476
# eig tensor(1.0161)
# tensor([-1.6775], grad_fn=<SelectBackward0>)
# 477
# eig tensor(0.9754)
# tensor([-1.6776], grad_fn=<SelectBackward0>)
# 478
# eig tensor(1.0076)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 479
# eig tensor(0.4722)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 480
# eig tensor(0.7523)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 481
# eig tensor(0.8858)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 482
# eig tensor(0.7829)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 483
# eig tensor(0.7995)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 484
# eig tensor(0.9314)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 485
# eig tensor(1.2495)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 486
# eig tensor(0.9678)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 487
# eig tensor(0.8132)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 488
# eig tensor(1.3850)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 489
# eig tensor(1.1255)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 490
# eig tensor(1.1915)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 491
# eig tensor(1.2824)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 492
# eig tensor(0.8881)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 493
# eig tensor(0.9173)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 494
# eig tensor(1.3816)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 495
# eig tensor(1.1107)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 496
# eig tensor(1.0244)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 497
# eig tensor(1.0949)
# tensor([-1.6788], grad_fn=<SelectBackward0>)
# 498
# eig tensor(1.5414)
# tensor([-1.6788], grad_fn=<SelectBackward0>)
# 499
# eig tensor(1.6067)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 500
# eig tensor(1.0200)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 501
# eig tensor(1.4638)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 502
# eig tensor(1.0244)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 503
# eig tensor(1.0218)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 504
# eig tensor(1.2426)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 505
# eig tensor(0.5508)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 506
# eig tensor(1.3376)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 507
# eig tensor(1.5712)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 508
# eig tensor(0.5000)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 509
# eig tensor(0.4749)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 510
# eig tensor(1.6707)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 511
# eig tensor(0.9362)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 512
# eig tensor(0.9503)
# tensor([-1.6793], grad_fn=<SelectBackward0>)
# 513
# eig tensor(0.1286)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 514
# eig tensor(0.8359)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 515
# eig tensor(0.8692)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 516
# eig tensor(1.1076)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 517
# eig tensor(1.0403)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 518
# eig tensor(0.7247)
# tensor([-1.6796], grad_fn=<SelectBackward0>)
# 519
# eig tensor(0.9270)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 520
# eig tensor(1.6362)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 521
# eig tensor(0.7178)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 522
# eig tensor(1.0045)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 523
# eig tensor(0.4933)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 524
# eig tensor(1.5709)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 525
# eig tensor(1.0347)
# tensor([-1.6793], grad_fn=<SelectBackward0>)
# 526
# eig tensor(1.1845)
# tensor([-1.6793], grad_fn=<SelectBackward0>)
# 527
# eig tensor(1.2790)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 528
# eig tensor(0.8951)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 529
# eig tensor(0.8084)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 530
# eig tensor(0.9372)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 531
# eig tensor(1.3314)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 532
# eig tensor(1.3702)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 533
# eig tensor(1.4497)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 534
# eig tensor(0.6091)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 535
# eig tensor(0.9044)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 536
# eig tensor(1.0389)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 537
# eig tensor(1.4175)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 538
# eig tensor(1.0945)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 539
# eig tensor(1.4870)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 540
# eig tensor(1.9826)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 541
# eig tensor(1.7832)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 542
# eig tensor(0.5941)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 543
# eig tensor(1.4619)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 544
# eig tensor(1.5661)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 545
# eig tensor(1.0875)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 546
# eig tensor(1.3241)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 547
# eig tensor(1.2327)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 548
# eig tensor(0.5165)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 549
# eig tensor(1.4169)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 550
# eig tensor(0.7522)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 551
# eig tensor(0.5377)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 552
# eig tensor(0.5135)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 553
# eig tensor(1.4291)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 554
# eig tensor(1.2624)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 555
# eig tensor(1.6454)
# tensor([-1.6781], grad_fn=<SelectBackward0>)
# 556
# eig tensor(1.0174)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 557
# eig tensor(0.8584)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 558
# eig tensor(1.1165)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 559
# eig tensor(1.1531)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 560
# eig tensor(1.0611)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 561
# eig tensor(1.0406)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 562
# eig tensor(0.7285)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 563
# eig tensor(0.7954)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 564
# eig tensor(0.7188)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 565
# eig tensor(1.1920)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 566
# eig tensor(1.5241)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 567
# eig tensor(1.5547)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 568
# eig tensor(0.6727)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 569
# eig tensor(0.5428)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 570
# eig tensor(0.6792)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 571
# eig tensor(0.5479)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 572
# eig tensor(0.4472)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 573
# eig tensor(1.5537)
# tensor([-1.6790], grad_fn=<SelectBackward0>)
# 574
# eig tensor(0.6786)
# tensor([-1.6792], grad_fn=<SelectBackward0>)
# 575
# eig tensor(0.7975)
# tensor([-1.6793], grad_fn=<SelectBackward0>)
# 576
# eig tensor(1.4545)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 577
# eig tensor(0.9659)
# tensor([-1.6795], grad_fn=<SelectBackward0>)
# 578
# eig tensor(1.2526)
# tensor([-1.6797], grad_fn=<SelectBackward0>)
# 579
# eig tensor(1.7535)
# tensor([-1.6798], grad_fn=<SelectBackward0>)
# 580
# eig tensor(0.7548)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 581
# eig tensor(0.6491)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 582
# eig tensor(0.7206)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 583
# eig tensor(0.2393)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 584
# eig tensor(1.0207)
# tensor([-1.6796], grad_fn=<SelectBackward0>)
# 585
# eig tensor(0.6270)
# tensor([-1.6794], grad_fn=<SelectBackward0>)
# 586
# eig tensor(0.8492)
# tensor([-1.6791], grad_fn=<SelectBackward0>)
# 587
# eig tensor(0.9823)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 588
# eig tensor(1.6246)
# tensor([-1.6788], grad_fn=<SelectBackward0>)
# 589
# eig tensor(0.5167)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 590
# eig tensor(1.7201)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 591
# eig tensor(0.8627)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 592
# eig tensor(1.5766)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 593
# eig tensor(0.5715)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 594
# eig tensor(0.9206)
# tensor([-1.6776], grad_fn=<SelectBackward0>)
# 595
# eig tensor(1.3647)
# tensor([-1.6775], grad_fn=<SelectBackward0>)
# 596
# eig tensor(0.2442)
# tensor([-1.6773], grad_fn=<SelectBackward0>)
# 597
# eig tensor(1.0407)
# tensor([-1.6772], grad_fn=<SelectBackward0>)
# 598
# eig tensor(0.7945)
# tensor([-1.6771], grad_fn=<SelectBackward0>)
# 599
# eig tensor(0.7836)
# tensor([-1.6770], grad_fn=<SelectBackward0>)
# 600
# eig tensor(0.4258)
# tensor([-1.6769], grad_fn=<SelectBackward0>)
# 601
# eig tensor(1.0592)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 602
# eig tensor(0.7785)
# tensor([-1.6768], grad_fn=<SelectBackward0>)
# 603
# eig tensor(1.1110)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 604
# eig tensor(0.8897)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 605
# eig tensor(0.7769)
# tensor([-1.6766], grad_fn=<SelectBackward0>)
# 606
# eig tensor(1.4889)
# tensor([-1.6766], grad_fn=<SelectBackward0>)
# 607
# eig tensor(1.2464)
# tensor([-1.6766], grad_fn=<SelectBackward0>)
# 608
# eig tensor(0.9627)
# tensor([-1.6767], grad_fn=<SelectBackward0>)
# 609
# eig tensor(0.7106)
# tensor([-1.6764], grad_fn=<SelectBackward0>)
# 610
# eig tensor(0.5099)
# tensor([-1.6761], grad_fn=<SelectBackward0>)
# 611
# eig tensor(0.2253)
# tensor([-1.6759], grad_fn=<SelectBackward0>)
# 612
# eig tensor(1.2719)
# tensor([-1.6758], grad_fn=<SelectBackward0>)
# 613
# eig tensor(0.5214)
# tensor([-1.6756], grad_fn=<SelectBackward0>)
# 614
# eig tensor(1.4918)
# tensor([-1.6754], grad_fn=<SelectBackward0>)
# 615
# eig tensor(1.1504)
# tensor([-1.6753], grad_fn=<SelectBackward0>)
# 616
# eig tensor(0.3430)
# tensor([-1.6753], grad_fn=<SelectBackward0>)
# 617
# eig tensor(1.3414)
# tensor([-1.6751], grad_fn=<SelectBackward0>)
# 618
# eig tensor(0.7820)
# tensor([-1.6750], grad_fn=<SelectBackward0>)
# 619
# eig tensor(1.3338)
# tensor([-1.6749], grad_fn=<SelectBackward0>)
# 620
# eig tensor(0.6699)
# tensor([-1.6748], grad_fn=<SelectBackward0>)
# 621
# eig tensor(1.3441)
# tensor([-1.6747], grad_fn=<SelectBackward0>)
# 622
# eig tensor(0.5496)
# tensor([-1.6746], grad_fn=<SelectBackward0>)
# 623
# eig tensor(0.7458)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 624
# eig tensor(0.9647)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 625
# eig tensor(0.8995)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 626
# eig tensor(0.7553)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 627
# eig tensor(1.7541)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 628
# eig tensor(0.7116)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 629
# eig tensor(1.2359)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 630
# eig tensor(1.3830)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 631
# eig tensor(1.1627)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 632
# eig tensor(0.8229)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 633
# eig tensor(1.0278)
# tensor([-1.6746], grad_fn=<SelectBackward0>)
# 634
# eig tensor(0.1693)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 635
# eig tensor(1.2465)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 636
# eig tensor(0.8567)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 637
# eig tensor(0.7568)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 638
# eig tensor(0.8232)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 639
# eig tensor(0.8204)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 640
# eig tensor(1.4580)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 641
# eig tensor(0.1579)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 642
# eig tensor(0.8303)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 643
# eig tensor(1.1545)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 644
# eig tensor(0.8701)
# tensor([-1.6746], grad_fn=<SelectBackward0>)
# 645
# eig tensor(0.7114)
# tensor([-1.6746], grad_fn=<SelectBackward0>)
# 646
# eig tensor(1.1190)
# tensor([-1.6747], grad_fn=<SelectBackward0>)
# 647
# eig tensor(1.1846)
# tensor([-1.6748], grad_fn=<SelectBackward0>)
# 648
# eig tensor(1.0752)
# tensor([-1.6749], grad_fn=<SelectBackward0>)
# 649
# eig tensor(1.5753)
# tensor([-1.6748], grad_fn=<SelectBackward0>)
# 650
# eig tensor(0.4068)
# tensor([-1.6747], grad_fn=<SelectBackward0>)
# 651
# eig tensor(1.2164)
# tensor([-1.6747], grad_fn=<SelectBackward0>)
# 652
# eig tensor(0.8682)
# tensor([-1.6746], grad_fn=<SelectBackward0>)
# 653
# eig tensor(1.2784)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 654
# eig tensor(1.1560)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 655
# eig tensor(0.2224)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 656
# eig tensor(0.9084)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 657
# eig tensor(0.1898)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 658
# eig tensor(0.5761)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 659
# eig tensor(0.8591)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 660
# eig tensor(0.4693)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 661
# eig tensor(1.3847)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 662
# eig tensor(1.2496)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 663
# eig tensor(0.4704)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 664
# eig tensor(0.8034)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 665
# eig tensor(0.1737)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 666
# eig tensor(1.0569)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 667
# eig tensor(0.9650)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 668
# eig tensor(0.9500)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 669
# eig tensor(0.5754)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 670
# eig tensor(1.1321)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 671
# eig tensor(1.1016)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 672
# eig tensor(0.7614)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 673
# eig tensor(1.0050)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 674
# eig tensor(1.0027)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 675
# eig tensor(0.8214)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 676
# eig tensor(1.4496)
# tensor([-1.6743], grad_fn=<SelectBackward0>)
# 677
# eig tensor(1.1880)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 678
# eig tensor(1.1846)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 679
# eig tensor(1.1720)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 680
# eig tensor(1.9153)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 681
# eig tensor(0.9164)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 682
# eig tensor(0.8053)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 683
# eig tensor(1.5182)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 684
# eig tensor(1.1527)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 685
# eig tensor(1.2325)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 686
# eig tensor(0.9944)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 687
# eig tensor(2.1717)
# tensor([-1.6744], grad_fn=<SelectBackward0>)
# 688
# eig tensor(1.5782)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 689
# eig tensor(0.8802)
# tensor([-1.6745], grad_fn=<SelectBackward0>)
# 690
# eig tensor(1.2637)
# tensor([-1.6747], grad_fn=<SelectBackward0>)
# 691
# eig tensor(1.5404)
# tensor([-1.6748], grad_fn=<SelectBackward0>)
# 692
# eig tensor(0.8376)
# tensor([-1.6750], grad_fn=<SelectBackward0>)
# 693
# eig tensor(0.8610)
# tensor([-1.6751], grad_fn=<SelectBackward0>)
# 694
# eig tensor(1.1877)
# tensor([-1.6752], grad_fn=<SelectBackward0>)
# 695
# eig tensor(0.3827)
# tensor([-1.6753], grad_fn=<SelectBackward0>)
# 696
# eig tensor(0.9272)
# tensor([-1.6754], grad_fn=<SelectBackward0>)
# 697
# eig tensor(1.1763)
# tensor([-1.6755], grad_fn=<SelectBackward0>)
# 698
# eig tensor(0.9806)
# tensor([-1.6756], grad_fn=<SelectBackward0>)
# 699
# eig tensor(1.3947)
# tensor([-1.6756], grad_fn=<SelectBackward0>)
# 700
# eig tensor(1.8052)
# tensor([-1.6757], grad_fn=<SelectBackward0>)
# 701
# eig tensor(1.1440)
# tensor([-1.6758], grad_fn=<SelectBackward0>)
# 702
# eig tensor(0.8501)
# tensor([-1.6758], grad_fn=<SelectBackward0>)
# 703
# eig tensor(1.2384)
# tensor([-1.6759], grad_fn=<SelectBackward0>)
# 704
# eig tensor(0.7492)
# tensor([-1.6758], grad_fn=<SelectBackward0>)
# 705
# eig tensor(1.2522)
# tensor([-1.6758], grad_fn=<SelectBackward0>)
# 706
# eig tensor(0.6322)
# ...
# eig tensor(0.9634)
# tensor([-1.6781], grad_fn=<SelectBackward0>)
# 765
# eig tensor(1.1804)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 766
# eig tensor(0.9129)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 767
# eig tensor(0.5007)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 768
# eig tensor(0.8103)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 769
# eig tensor(0.6487)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 770
# eig tensor(1.2347)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 771
# eig tensor(0.6909)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 772
# eig tensor(1.0829)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 773
# eig tensor(1.3867)
# tensor([-1.6788], grad_fn=<SelectBackward0>)
# 774
# eig tensor(0.7642)
# tensor([-1.6787], grad_fn=<SelectBackward0>)
# 775
# eig tensor(0.7672)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 776
# eig tensor(0.4254)
# tensor([-1.6786], grad_fn=<SelectBackward0>)
# 777
# eig tensor(0.8710)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 778
# eig tensor(0.9756)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 779
# eig tensor(0.8379)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 780
# eig tensor(1.2907)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 781
# eig tensor(0.9804)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 782
# eig tensor(0.9947)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 783
# eig tensor(0.9269)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 784
# eig tensor(0.0166)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 785
# eig tensor(0.7984)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 786
# eig tensor(0.9629)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 787
# eig tensor(1.1585)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 788
# eig tensor(0.7914)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 789
# eig tensor(1.4024)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 790
# eig tensor(0.9985)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 791
# eig tensor(0.8226)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 792
# eig tensor(1.0994)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 793
# eig tensor(0.5833)
# tensor([-1.6785], grad_fn=<SelectBackward0>)
# 794
# eig tensor(0.7802)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 795
# eig tensor(0.4863)
# tensor([-1.6784], grad_fn=<SelectBackward0>)
# 796
# eig tensor(1.1170)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 797
# eig tensor(0.8128)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 798
# eig tensor(0.8958)
# tensor([-1.6783], grad_fn=<SelectBackward0>)
# 799
# eig tensor(1.3317)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 800
# eig tensor(1.4917)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 801
# eig tensor(0.5485)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 802
# eig tensor(0.3537)
# tensor([-1.6782], grad_fn=<SelectBackward0>)
# 803
# eig tensor(0.7719)
# tensor([-1.6781], grad_fn=<SelectBackward0>)
# 804
# eig tensor(1.4945)
# tensor([-1.6781], grad_fn=<SelectBackward0>)
# 805
# eig tensor(1.0799)
# tensor([-1.6781], grad_fn=<SelectBackward0>)
# 806
# eig tensor(0.1645)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 807
# eig tensor(0.8571)
# tensor([-1.6780], grad_fn=<SelectBackward0>)
# 808
# eig tensor(1.4476)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 809
# eig tensor(0.9202)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 810
# eig tensor(1.6065)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 811
# eig tensor(0.7164)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 812
# eig tensor(1.0732)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 813
# eig tensor(1.3335)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 814
# eig tensor(0.4019)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 815
# eig tensor(0.8411)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 816
# eig tensor(0.8881)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 817
# eig tensor(1.0725)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 818
# eig tensor(1.0381)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 819
# eig tensor(0.5908)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 820
# eig tensor(1.6987)
# tensor([-1.6779], grad_fn=<SelectBackward0>)
# 821
# eig tensor(0.6037)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 822
# eig tensor(0.8805)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 823
# eig tensor(0.4963)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 824
# eig tensor(1.3698)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 825
# eig tensor(1.6087)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 826
# eig tensor(0.9498)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 827
# eig tensor(1.3943)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 828
# eig tensor(0.9980)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 829
# eig tensor(0.7765)
# tensor([-1.6777], grad_fn=<SelectBackward0>)
# 830
# eig tensor(1.0097)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 831
# eig tensor(1.1944)
# tensor([-1.6778], grad_fn=<SelectBackward0>)
# 832
# eig tensor(1.6340)
# tensor([-1.6789], grad_fn=<SelectBackward0>)
# 833
# eig tensor(0.8102)
# tensor([-1.6799], grad_fn=<SelectBackward0>)
# 834
# eig tensor(1.6007)
# tensor([-1.6808], grad_fn=<SelectBackward0>)
# 835
# eig tensor(1.0955)
# tensor([-1.6817], grad_fn=<SelectBackward0>)
# 836
# eig tensor(1.4273)
# tensor([-1.6823], grad_fn=<SelectBackward0>)
# 837
# eig tensor(0.0212)
# tensor([-1.6829], grad_fn=<SelectBackward0>)
# 838
# eig tensor(1.6283)
# tensor([-1.6834], grad_fn=<SelectBackward0>)
# 839
# eig tensor(1.3082)
# tensor([-1.6839], grad_fn=<SelectBackward0>)
# 840
# eig tensor(1.2774)
# tensor([-1.6845], grad_fn=<SelectBackward0>)
# 841
# eig tensor(0.6584)
# tensor([-1.6851], grad_fn=<SelectBackward0>)
# 842
# eig tensor(0.3910)
# tensor([-1.6857], grad_fn=<SelectBackward0>)
# 843
# eig tensor(0.9825)
# tensor([-1.6862], grad_fn=<SelectBackward0>)
# 844
# eig tensor(0.9429)
# tensor([-1.6866], grad_fn=<SelectBackward0>)
# 845
# eig tensor(1.6263)
# tensor([-1.6870], grad_fn=<SelectBackward0>)
# 846
# eig tensor(0.9877)
# tensor([-1.6874], grad_fn=<SelectBackward0>)
# 847
# eig tensor(0.7297)
# tensor([-1.6878], grad_fn=<SelectBackward0>)
# 848
# eig tensor(1.4085)
# tensor([-1.6882], grad_fn=<SelectBackward0>)
# 849
# eig tensor(1.2617)
# tensor([-1.6885], grad_fn=<SelectBackward0>)
# 850
# eig tensor(0.9618)
# tensor([-1.6888], grad_fn=<SelectBackward0>)
# 851
# eig tensor(1.0126)
# tensor([-1.6890], grad_fn=<SelectBackward0>)
# 852
# eig tensor(1.5820)
# tensor([-1.6893], grad_fn=<SelectBackward0>)
# 853
# eig tensor(1.4457)
# tensor([-1.6895], grad_fn=<SelectBackward0>)
# 854
# eig tensor(0.9775)
# tensor([-1.6897], grad_fn=<SelectBackward0>)
# 855
# eig tensor(1.1148)
# tensor([-1.6899], grad_fn=<SelectBackward0>)
# 856
# eig tensor(1.2249)
# tensor([-1.6900], grad_fn=<SelectBackward0>)
# 857
# eig tensor(1.5636)
# tensor([-1.6902], grad_fn=<SelectBackward0>)
# 858
# eig tensor(1.2779)
# tensor([-1.6903], grad_fn=<SelectBackward0>)
# 859
# eig tensor(1.2863)
# tensor([-1.6904], grad_fn=<SelectBackward0>)
# 860
# eig tensor(1.1038)
# tensor([-1.6905], grad_fn=<SelectBackward0>)
# 861
# eig tensor(1.8857)
# tensor([-1.6906], grad_fn=<SelectBackward0>)
# 862
# eig tensor(1.2178)
# tensor([-1.6907], grad_fn=<SelectBackward0>)
# 863
# eig tensor(0.6255)
# tensor([-1.6908], grad_fn=<SelectBackward0>)
# 864
# eig tensor(1.0989)
# tensor([-1.6909], grad_fn=<SelectBackward0>)
# 865
# eig tensor(0.5637)
# tensor([-1.6910], grad_fn=<SelectBackward0>)
# 866
# eig tensor(0.7417)
# tensor([-1.6910], grad_fn=<SelectBackward0>)
# 867
# eig tensor(1.0987)
# tensor([-1.6911], grad_fn=<SelectBackward0>)
# 868
# eig tensor(1.2845)
# tensor([-1.6912], grad_fn=<SelectBackward0>)
# 869
# eig tensor(1.0726)
# tensor([-1.6913], grad_fn=<SelectBackward0>)
# 870
# eig tensor(1.3136)
# tensor([-1.6914], grad_fn=<SelectBackward0>)
# 871
# eig tensor(1.3420)
# tensor([-1.6915], grad_fn=<SelectBackward0>)
# 872
# eig tensor(1.6385)
# tensor([-1.6916], grad_fn=<SelectBackward0>)
# 873
# eig tensor(1.3608)
# tensor([-1.6915], grad_fn=<SelectBackward0>)
# 874
# eig tensor(1.1613)
# tensor([-1.6915], grad_fn=<SelectBackward0>)
# 875
# eig tensor(1.1674)
# tensor([-1.6914], grad_fn=<SelectBackward0>)
# 876
# eig tensor(0.6827)
# tensor([-1.6915], grad_fn=<SelectBackward0>)
# 877
# eig tensor(0.4460)
# tensor([-1.6915], grad_fn=<SelectBackward0>)
# 878
# eig tensor(1.2851)
# tensor([-1.6916], grad_fn=<SelectBackward0>)
# 879
# eig tensor(0.8379)
# tensor([-1.6916], grad_fn=<SelectBackward0>)
# 880
# eig tensor(1.2716)
# tensor([-1.6916], grad_fn=<SelectBackward0>)
# 881
# eig tensor(0.6455)
# tensor([-1.6916], grad_fn=<SelectBackward0>)
# 882
# eig tensor(0.6808)
# tensor([-1.6917], grad_fn=<SelectBackward0>)
# 883
# eig tensor(0.4349)
# tensor([-1.6918], grad_fn=<SelectBackward0>)
# 884
# eig tensor(0.4546)
# tensor([-1.6919], grad_fn=<SelectBackward0>)
# 885
# eig tensor(1.1250)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 886
# eig tensor(1.4662)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 887
# eig tensor(1.0488)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 888
# eig tensor(1.8750)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 889
# eig tensor(0.5494)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 890
# eig tensor(0.9497)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 891
# eig tensor(1.2380)
# tensor([-1.6922], grad_fn=<SelectBackward0>)
# 892
# eig tensor(1.0355)
# tensor([-1.6923], grad_fn=<SelectBackward0>)
# 893
# eig tensor(1.4361)
# tensor([-1.6923], grad_fn=<SelectBackward0>)
# 894
# eig tensor(0.5935)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 895
# eig tensor(0.6603)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 896
# eig tensor(0.8462)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 897
# eig tensor(0.8430)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 898
# eig tensor(1.6001)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 899
# eig tensor(1.9378)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 900
# eig tensor(0.9534)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 901
# eig tensor(1.8388)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 902
# eig tensor(0.7961)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 903
# eig tensor(1.7577)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 904
# eig tensor(1.0224)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 905
# eig tensor(0.6618)
# tensor([-1.6923], grad_fn=<SelectBackward0>)
# 906
# eig tensor(0.8450)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 907
# eig tensor(1.0667)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 908
# eig tensor(0.7255)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 909
# eig tensor(1.4358)
# tensor([-1.6919], grad_fn=<SelectBackward0>)
# 910
# eig tensor(0.5323)
# tensor([-1.6919], grad_fn=<SelectBackward0>)
# 911
# eig tensor(1.2315)
# tensor([-1.6918], grad_fn=<SelectBackward0>)
# 912
# eig tensor(0.7979)
# tensor([-1.6918], grad_fn=<SelectBackward0>)
# 913
# eig tensor(1.5102)
# tensor([-1.6917], grad_fn=<SelectBackward0>)
# 914
# eig tensor(1.2086)
# tensor([-1.6917], grad_fn=<SelectBackward0>)
# 915
# eig tensor(1.2216)
# tensor([-1.6918], grad_fn=<SelectBackward0>)
# 916
# eig tensor(0.2059)
# tensor([-1.6919], grad_fn=<SelectBackward0>)
# 917
# eig tensor(1.1652)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 918
# eig tensor(1.4812)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 919
# eig tensor(1.1477)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 920
# eig tensor(0.9274)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 921
# eig tensor(1.3907)
# tensor([-1.6922], grad_fn=<SelectBackward0>)
# 922
# eig tensor(0.7111)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 923
# eig tensor(0.8057)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 924
# eig tensor(1.0763)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 925
# eig tensor(0.9409)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 926
# eig tensor(0.7453)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 927
# eig tensor(1.1494)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 928
# eig tensor(0.5499)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 929
# eig tensor(1.4747)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 930
# eig tensor(0.6076)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 931
# eig tensor(0.9268)
# tensor([-1.6920], grad_fn=<SelectBackward0>)
# 932
# eig tensor(0.7960)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 933
# eig tensor(0.3997)
# tensor([-1.6921], grad_fn=<SelectBackward0>)
# 934
# eig tensor(2.0662)
# tensor([-1.6922], grad_fn=<SelectBackward0>)
# 935
# eig tensor(1.3271)
# tensor([-1.6922], grad_fn=<SelectBackward0>)
# 936
# eig tensor(1.4370)
# tensor([-1.6923], grad_fn=<SelectBackward0>)
# 937
# eig tensor(1.6671)
# tensor([-1.6924], grad_fn=<SelectBackward0>)
# 938
# eig tensor(0.9850)
# tensor([-1.6925], grad_fn=<SelectBackward0>)
# 939
# eig tensor(1.1338)
# tensor([-1.6926], grad_fn=<SelectBackward0>)
# 940
# eig tensor(1.6588)
# tensor([-1.6927], grad_fn=<SelectBackward0>)
# 941
# eig tensor(1.5195)
# tensor([-1.6928], grad_fn=<SelectBackward0>)
# 942
# eig tensor(0.7072)
# tensor([-1.6928], grad_fn=<SelectBackward0>)
# 943
# eig tensor(1.0310)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 944
# eig tensor(1.4443)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 945
# eig tensor(1.3491)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 946
# eig tensor(0.6851)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 947
# eig tensor(1.0596)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 948
# eig tensor(0.9081)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 949
# eig tensor(1.0860)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 950
# eig tensor(1.3601)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 951
# eig tensor(1.8149)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 952
# eig tensor(1.5792)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 953
# eig tensor(1.0630)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 954
# eig tensor(1.4553)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 955
# eig tensor(0.4978)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 956
# eig tensor(1.2484)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 957
# eig tensor(1.2445)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 958
# eig tensor(0.8726)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 959
# eig tensor(0.9781)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 960
# eig tensor(1.6683)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 961
# eig tensor(1.8107)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 962
# eig tensor(1.2808)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 963
# eig tensor(1.8180)
# tensor([-1.6928], grad_fn=<SelectBackward0>)
# 964
# eig tensor(0.8717)
# tensor([-1.6928], grad_fn=<SelectBackward0>)
# 965
# eig tensor(0.8022)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 966
# eig tensor(1.7665)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 967
# eig tensor(0.8830)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 968
# eig tensor(0.9191)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 969
# eig tensor(0.7833)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 970
# eig tensor(0.3973)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 971
# eig tensor(0.7119)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 972
# eig tensor(1.3688)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 973
# eig tensor(1.6678)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 974
# eig tensor(0.9205)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 975
# eig tensor(0.4862)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 976
# eig tensor(1.4286)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 977
# eig tensor(0.6976)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 978
# eig tensor(1.1823)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 979
# eig tensor(1.0830)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 980
# eig tensor(0.6673)
# tensor([-1.6929], grad_fn=<SelectBackward0>)
# 981
# eig tensor(1.2849)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 982
# eig tensor(1.0272)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 983
# eig tensor(1.1487)
# tensor([-1.6930], grad_fn=<SelectBackward0>)
# 984
# eig tensor(1.2517)
# tensor([-1.6931], grad_fn=<SelectBackward0>)
# 985
# eig tensor(1.7564)
# tensor([-1.6932], grad_fn=<SelectBackward0>)
# 986
# eig tensor(0.3580)
# tensor([-1.6933], grad_fn=<SelectBackward0>)
# 987
# eig tensor(1.5155)
# tensor([-1.6934], grad_fn=<SelectBackward0>)
# 988
# eig tensor(1.4809)
# tensor([-1.6935], grad_fn=<SelectBackward0>)
# 989
# eig tensor(0.7934)
# tensor([-1.6937], grad_fn=<SelectBackward0>)
# 990
# eig tensor(1.2712)
# tensor([-1.6937], grad_fn=<SelectBackward0>)
# 991
# eig tensor(0.8477)
# tensor([-1.6937], grad_fn=<SelectBackward0>)
# 992
# eig tensor(1.0876)
# tensor([-1.6937], grad_fn=<SelectBackward0>)
# 993
# eig tensor(0.6239)
# tensor([-1.6937], grad_fn=<SelectBackward0>)
# 994
# eig tensor(1.3288)
# tensor([-1.6938], grad_fn=<SelectBackward0>)
# 995
# eig tensor(0.5855)
# tensor([-1.6938], grad_fn=<SelectBackward0>)
# 996
# eig tensor(1.1147)
# tensor([-1.6939], grad_fn=<SelectBackward0>)
# 997
# eig tensor(1.1328)
# tensor([-1.6939], grad_fn=<SelectBackward0>)
# 998
# eig tensor(0.8891)
# tensor([-1.6940], grad_fn=<SelectBackward0>)
# 999
# eig tensor(0.9335)
