# %%
import wandb
api = wandb.Api()
runs = api.runs("vz_uci/lfiax_lf-pce_3D")

# %%
project_name = "my-project"

run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        data = file.download(root="./downloads/")
        # print(dir(run_data))
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:26, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      25 try:
# ---> 26     return func(*args, **kwargs)
#      27 except requests.HTTPError as err:
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     130 try:
# --> 131     result = self._call_fn(*args, **kwargs)
#     132     # Only print resolved attempts once every minute
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:2820, in File.download(self, root, replace, exist_ok)
#    2819     else:
# -> 2820         raise ValueError(
#    2821             "File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error."
#    2822         )
#    2824 util.download_file_from_url(path, self.url, Api().api_key)
#
# ValueError: File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error.
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In [26], line 9
#       4 for run in runs:
#       5     for file in run.files():
#       6         # if file.type == "metadata":
#       7         #     # Skip metadata files
#       8         #     continue
# ----> 9         data = file.download(root="./downloads/")
#      10         # print(dir(run_data))
#      11         run_data.append({
#      12             "run_id": run.id,
#      13             "file_name": file.name,
#      14             "file_data": data,
#      15         })
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:64, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      62     raise
#      63 else:
# ---> 64     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:26, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      24 message = "Whoa, you found a bug."
#      25 try:
# ---> 26     return func(*args, **kwargs)
#      27 except requests.HTTPError as err:
#      28     raise CommError(err.response, err)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:2820, in File.download(self, root, replace, exist_ok)
#    2818         return open(path)
#    2819     else:
# -> 2820         raise ValueError(
#    2821             "File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error."
#    2822         )
#    2824 util.download_file_from_url(path, self.url, Api().api_key)
#    2825 return open(path)
#
# CommError: File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error.

# %%
type(runs)
# Out:
# wandb.apis.public.Runs

# %%
# Download all the files for each run
run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        file_path = f"./downloads/{file.name}"
        if os.path.exists(file_path):
            # File already exists, skip downloading it
            continue
        try:
            data = file.download(root="./downloads/")
        except wandb.CommError as e:
            if "File already exists" in str(e):
                # File already exists, skip downloading it
                continue
            else:
                raise e
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })

# %%
len(run_data)
# Out:
# 10

# %%
import pandas as pd

df = pd.DataFrame(run_data)

# %%
df
# Out:
#      run_id                               file_name  \
# 0  vti9vucv                  conda-environment.yaml
# 1  vti9vucv                             config.yaml
# 2  vti9vucv                              output.log
# 3  vti9vucv                        requirements.txt
# 4  vti9vucv                     wandb-metadata.json
# 5  vti9vucv                      wandb-summary.json
# 6  k81862ba  artifact/388642138/wandb_manifest.json
# 7  drffv8ls  artifact/388642121/wandb_manifest.json
# 8  5ydy3oon  artifact/388642145/wandb_manifest.json
# 9  2ua46uq4  artifact/388623620/wandb_manifest.json
#
#                                            file_data
# 0  <_io.TextIOWrapper name='./downloads/conda-env...
# 1  <_io.TextIOWrapper name='./downloads/config.ya...
# 2  <_io.TextIOWrapper name='./downloads/output.lo...
# 3  <_io.TextIOWrapper name='./downloads/requireme...
# 4  <_io.TextIOWrapper name='./downloads/wandb-met...
# 5  <_io.TextIOWrapper name='./downloads/wandb-sum...
# 6  <_io.TextIOWrapper name='./downloads/artifact/...
# 7  <_io.TextIOWrapper name='./downloads/artifact/...
# 8  <_io.TextIOWrapper name='./downloads/artifact/...
# 9  <_io.TextIOWrapper name='./downloads/artifact/...

# %%
# Extract the "xi" data from the log files
xi_data = pd.DataFrame()
for index, row in df.iterrows():
    # Split the log file into lines
    lines = row["log_data"].split("\n")
    for line in lines:
        # Check if the line contains "xi"
        if "xi" in line:
            # Extract the "xi" value from the line
            xi_value = line.split(" ")[-1]
            # Add the "xi" value to the DataFrame
            xi_data.loc[row["run_id"], len(xi_data.columns)] = float(xi_value)

# Print the "xi" data
print(xi_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'log_data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [39], line 5
#       2 xi_data = pd.DataFrame()
#       3 for index, row in df.iterrows():
#       4     # Split the log file into lines
# ----> 5     lines = row["log_data"].split("\n")
#       6     for line in lines:
#       7         # Check if the line contains "xi"
#       8         if "xi" in line:
#       9             # Extract the "xi" value from the line
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'log_data'

# %%
run_data = []
for run in runs:
    log_file = None
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        if file.name.endswith(".log"):
            # Save the path to the log file
            log_file = file.name
        # Download the file to the destination folder
        file.download(root="./downloads", exist_ok=True)
    if log_file is not None:
        # Read the contents of the log file into a Pandas DataFrame
        log_path = os.path.join("./downloads", log_file)
        log_data = pd.read_csv(log_path, delimiter="\t", names=["step", "key", "value"])
        xi_data = log_data[log_data["key"] == "xi"]
        xi_data = xi_data.drop(["key"], axis=1)
        xi_data = xi_data.rename(columns={"value": run.id})
        xi_data.set_index("step", inplace=True)
        run_data.append(xi_data)

# Concatenate the "xi" data from all runs into a single DataFrame
xi_data = pd.concat(run_data, axis=1)
runs_list = xi_data.columns.tolist()

# Print the "xi" data
print(xi_data)
# Out:
# Empty DataFrame
# Columns: [wv11gi20, vmlaenxn, st0j07aw, pqtlrvli, ma8ed5a2, gf2s8arc, ga22dptz, 9mirs9mg, 9hy1ixq1, 7t6k656n, 6il08nqc, 5v9bqqtr, 5hgy65ao, 0ctdqru0, t7qjuwtc, qzaquzql, mvgzvpb7, lkfjflpb, g5wk86cy, a5ov2jp8, 84wzz122, 83hm1aqm, 5vrdr9hh, 2bvve01x, vti9vucv, qcfm7w12, 928mx08q, zfdpm9ye, wd3be2nt, uroq913x, uq05hd62, mxilke43, k81862ba, hkotq2bc, drffv8ls, do6dfs77, dc4brjqn, 91rovnay, 62682s91, 5ydy3oon, 55z8tajj, 4h5bnhzq, 1z8v8ma6, 1yf683j7, 1cfjacq8, ab2yi2rc, 2ua46uq4]
# Index: []
#
# [0 rows x 47 columns]

# %%
xi_data
# Out:
# Empty DataFrame
# Columns: [vti9vucv, qcfm7w12, 928mx08q, zfdpm9ye, wd3be2nt, uroq913x, uq05hd62, mxilke43, k81862ba, hkotq2bc, drffv8ls, do6dfs77, dc4brjqn, 91rovnay, 62682s91, 5ydy3oon, 55z8tajj, 4h5bnhzq, 1z8v8ma6, 1yf683j7, 1cfjacq8, ab2yi2rc, 2ua46uq4]
# Index: []
#
# [0 rows x 23 columns]

# %%
api = wandb.Api()

# List of runs (run IDs)
runs_list = xi_data.columns.tolist()

# Dictionary to store the data for each run
data_dict = {}

# Loop over the runs and get the data for each run
for run_id in runs_list:
    # Get the run object
    run = api.run(run_id)
    
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

# Combine the data for all runs into a single dataframe
df = pd.concat(data_dict.values(), keys=data_dict.keys(), names=["run_id", "step"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:26, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      25 try:
# ---> 26     return func(*args, **kwargs)
#      27 except requests.HTTPError as err:
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:878, in Api.run(self, path)
#     877 if not self._runs.get(path):
# --> 878     self._runs[path] = Run(self.client, entity, project, run_id)
#     879 return self._runs[path]
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1718, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1716 self._state = _attrs.get("state", "not found")
# -> 1718 self.load(force=not _attrs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1822, in Run.load(self, force)
#    1817 if (
#    1818     response is None
#    1819     or response.get("project") is None
#    1820     or response["project"].get("run") is None
#    1821 ):
# -> 1822     raise ValueError("Could not find run %s" % self)
#    1823 self._attrs = response["project"]["run"]
#
# ValueError: Could not find run <Run vz_uci/wv11gi20/wv11gi20 (not found)>
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In [138], line 12
#       9 # Loop over the runs and get the data for each run
#      10 for run_id in runs_list:
#      11     # Get the run object
# ---> 12     run = api.run(run_id)
#      14     # Get the data associated with the "xi" key
#      15     xi_data = run.history(keys=["xi"])
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:64, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      62     raise
#      63 else:
# ---> 64     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:26, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      24 message = "Whoa, you found a bug."
#      25 try:
# ---> 26     return func(*args, **kwargs)
#      27 except requests.HTTPError as err:
#      28     raise CommError(err.response, err)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:878, in Api.run(self, path)
#     876 entity, project, run_id = self._parse_path(path)
#     877 if not self._runs.get(path):
# --> 878     self._runs[path] = Run(self.client, entity, project, run_id)
#     879 return self._runs[path]
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1718, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1715 self._summary = None
#    1716 self._state = _attrs.get("state", "not found")
# -> 1718 self.load(force=not _attrs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1822, in Run.load(self, force)
#    1816 response = self._exec(query)
#    1817 if (
#    1818     response is None
#    1819     or response.get("project") is None
#    1820     or response["project"].get("run") is None
#    1821 ):
# -> 1822     raise ValueError("Could not find run %s" % self)
#    1823 self._attrs = response["project"]["run"]
#    1824 self._state = self._attrs["state"]
#
# CommError: Could not find run <Run vz_uci/wv11gi20/wv11gi20 (not found)>

# %%
entity = "vz_uci"
project = "lfiax_lf-pce_3D"

for run_id in runs_list:
    run = api.run(f"{entity}/{project}/{run_id}")
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

# %%
data_dict['vti9vucv'].shape
# Out:
# (500, 2)

# %%
len(xi_data)
# Out:
# 500

# %%
from itertools import islice

# Create a new dictionary that only contains the first 10 items of data_dict
last_10_items = dict(list(data_dict.items())[-10:])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(last_10_items.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
last_five = {k: v[-1:] for k, v in data_dict.items()}
last_five
# Out:
# {'vti9vucv':      _step                           xi
#  499   9993  [[NaN, NaN, NaN, NaN, NaN]],
#  'qcfm7w12':      _step                                                 xi
#  499   9988  [[-1.3005709648132324, -2.1989569664001465, -0...,
#  '928mx08q':      _step                           xi
#  499   9983  [[NaN, NaN, NaN, NaN, NaN]],
#  'zfdpm9ye':      _step                                                 xi
#  499   9990  [[-5.001311302185059, 10, 9.2000093460083, 9.1...,
#  'wd3be2nt':      _step                                                 xi
#  499   9952  [[-2.2002625465393066, 0.3990784287452698, 3.7...,
#  'uroq913x':      _step                                                 xi
#  499   9931  [[-8.799710273742676, 0.8632327914237976, 0.09...,
#  'uq05hd62':      _step                           xi
#  499   9992  [[NaN, NaN, NaN, NaN, NaN]],
#  'mxilke43':      _step                           xi
#  499   9997  [[NaN, NaN, NaN, NaN, NaN]],
#  'k81862ba':      _step                           xi
#  499   9998  [[NaN, NaN, NaN, NaN, NaN]],
#  'hkotq2bc':      _step                           xi
#  499   9984  [[NaN, NaN, NaN, NaN, NaN]],
#  'drffv8ls':      _step                           xi
#  499   9977  [[NaN, NaN, NaN, NaN, NaN]],
#  'do6dfs77':      _step                                                 xi
#  499   9960  [[-9.000046730041504, 8.799894332885742, -9.29...,
#  'dc4brjqn':      _step                                                 xi
#  499   9982  [[-1.2004597187042236, -1.3998961448669434, 5....,
#  '91rovnay':      _step                           xi
#  499   9998  [[NaN, NaN, NaN, NaN, NaN]],
#  '62682s91':      _step                           xi
#  499   9989  [[NaN, NaN, NaN, NaN, NaN]],
#  '5ydy3oon':      _step                           xi
#  499   9999  [[NaN, NaN, NaN, NaN, NaN]],
#  '55z8tajj':      _step                           xi
#  499   9951  [[NaN, NaN, NaN, NaN, NaN]],
#  '4h5bnhzq':      _step                                                 xi
#  499   9966  [[-4.60032844543457, 1.099918007850647, -1.401...,
#  '1z8v8ma6':      _step                                                 xi
#  499   9994  [[-5.400033950805664, -9.50008773803711, 9.199...,
#  '1yf683j7':      _step                           xi
#  499   9935  [[NaN, NaN, NaN, NaN, NaN]],
#  '1cfjacq8':      _step                                                 xi
#  499   9989  [[2.899975538253784, -6.5002546310424805, 6.90...,
#  'ab2yi2rc':      _step                                                 xi
#  499   9997  [[-0.9000678062438965, -0.08400087803602219, 5...,
#  '2ua46uq4':      _step                                                 xi
#  499   9996  [[-9.80000114440918, -5.8006367683410645, -0.9...}

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Run")
ax.set_ylabel("Xi Value")
ax.set_title("Final Xi Value for Each Run")

# Get the last xi value for each run
last_xi_values = {}
for run, xi_data in data_dict.items():
    last_xi_values[run] = xi_data.iloc[-1]["xi"]

# Plot the last xi values as a bar chart
colors = plt.cm.tab20(np.linspace(0, 1, len(last_xi_values)))
x_ticks = range(len(last_xi_values))
for i, (run, xi_values) in enumerate(last_xi_values.items()):
    ax.bar(i, xi_values[-1], color=colors[i], label=f"Run {run}")

# Set the x-ticks to the run names
ax.set_xticks(x_ticks)
ax.set_xticklabels(last_xi_values.keys())

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Plot the last xi value for each run that doesn't have NaN values
fig, ax = plt.subplots()
ax.set_xlabel("Run")
ax.set_ylabel("Xi Value")
ax.set_title("Final Xi Value for Each Run")

# Keep track of the color index for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))

# Keep track of the x position for each bar
x_pos = []

for i, (run, xi_data) in enumerate(data_dict.items()):
    # Check if the xi array for this run has any NaN values
    # if not np.isnan(xi_data.iloc[-1]["xi"]).any():
    # Get the last xi value for this run
    xi_values = xi_data.iloc[-1]["xi"]
    # Add the bar to the plot
    for j, xi_value in enumerate(xi_values):
        ax.bar(i, xi_value, color=colors[i], label=f"Run {run} ({j+1})")
    x_pos.append(i)

# Set the x-axis labels and limits
ax.set_xticks(x_pos)
ax.set_xticklabels([f"Run {run}" for run in data_dict.keys()])
plt.xticks(rotation=45, ha='right')
ax.set_xlim(-0.5, len(x_pos)-0.5)

ax.set_yticks(np.arange(-10, 11, 1))
ax.set_ylim(-10, 10)

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Create a figure and axis for the plot
fig, ax = plt.subplots()
ax.set_xlabel("Run")
ax.set_ylabel("Xi Value")
ax.set_title("Final Xi Values Xi_LR=1e-1")

# Get a list of colors for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))

# Loop through each run and plot the final xi value as a scatter point
for i, (run, xi_data) in enumerate(data_dict.items()):
    # Extract the final xi values from the history data
    xi_values = xi_data.iloc[-1]["xi"]
    # Convert any string values to floats
    xi_values = [float(val) if type(val) == str else val for val in xi_values]
    # Create a list of x-axis values with the same length as xi_values
    x_vals = [i] * len(xi_values[0])
    # Plot the xi value as a scatter point
    ax.scatter(x_vals, xi_values, color=colors[i], label=f"Run {run}")

# Set the x-tick labels to the run names
ax.set_xticks(list(range(len(data_dict))))
ax.set_xticklabels(list(data_dict.keys()), rotation=90)

# Set the y-axis limits and labels
ax.set_ylim(-10, 10)
ax.set_yticks(list(range(-10, 11)))
ax.set_yticklabels(list(range(-10, 11)))

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Create a new dictionary that only contains the first 10 items of data_dict
last_10_items = dict(list(data_dict.items())[-10:])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(last_10_items.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Create a new dictionary that only contains the first 10 items of data_dict
last_10_items = dict(list(data_dict.items())[:23])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(last_10_items.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
import wandb

api = wandb.Api()
runs = api.runs("vz_uci/lfiax_5d_stupidAdam")

# Download all the files for each run
run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        file_path = f"./downloads/{file.name}"
        if os.path.exists(file_path):
            # File already exists, skip downloading it
            continue
        try:
            data = file.download(root="./downloads/")
        except wandb.CommError as e:
            if "File already exists" in str(e):
                # File already exists, skip downloading it
                continue
            else:
                raise e
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })

# %%
import pandas as pd

for run in runs:
    log_file = None
    for file in run.files():
        if file.name.endswith(".log"):
            # Save the path to the log file
            log_file = file.name
        # Download the file to the destination folder
        file.download(root="./downloads", exist_ok=True)
    if log_file is not None:
        # Read the contents of the log file into a Pandas DataFrame
        log_path = os.path.join("./downloads", log_file)
        log_data = pd.read_csv(log_path, delimiter="\t", names=["step", "key", "value"])
        xi_data = log_data[log_data["key"] == "xi"]
        xi_data = xi_data.drop(["key"], axis=1)
        xi_data = xi_data.rename(columns={"value": run.id})
        xi_data.set_index("step", inplace=True)
        run_data.append(xi_data)

# Concatenate the "xi" data from all runs into a single DataFrame
xi_data = pd.concat(run_data, axis=1)
runs_list = xi_data.columns.tolist()

# %%
entity = "vz_uci"
project = "lfiax_5d_stupidAdam"

data_dict = {}

for run_id in runs_list:
    run = api.run(f"{entity}/{project}/{run_id}")
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(data_dict.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
import pandas as pd
import wandb

entity = "vz_uci"
project = "lfiax_5d_stupidAdam_designRegularize"

api = wandb.Api()
runs = api.runs(f"{entity}/{project}")

# Download all the files for each run
run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        file_path = f"./downloads/{file.name}"
        if os.path.exists(file_path):
            # File already exists, skip downloading it
            continue
        try:
            data = file.download(root="./downloads/")
        except wandb.CommError as e:
            if "File already exists" in str(e):
                # File already exists, skip downloading it
                continue
            else:
                raise e
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })


for run in runs:
    log_file = None
    for file in run.files():
        if file.name.endswith(".log"):
            # Save the path to the log file
            log_file = file.name
        # Download the file to the destination folder
        file.download(root="./downloads", exist_ok=True)
    if log_file is not None:
        # Read the contents of the log file into a Pandas DataFrame
        log_path = os.path.join("./downloads", log_file)
        log_data = pd.read_csv(log_path, delimiter="\t", names=["step", "key", "value"])
        xi_data = log_data[log_data["key"] == "xi"]
        xi_data = xi_data.drop(["key"], axis=1)
        xi_data = xi_data.rename(columns={"value": run.id})
        xi_data.set_index("step", inplace=True)
        run_data.append(xi_data)

# Concatenate the "xi" data from all runs into a single DataFrame
xi_data = pd.concat(run_data, axis=1)
runs_list = xi_data.columns.tolist()

# %%
import matplotlib.pyplot as plt
import numpy as np

data_dict = {}

for run_id in runs_list:
    run = api.run(f"{entity}/{project}/{run_id}")
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

last_10_items = dict(list(data_dict.items())[-10:])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(data_dict.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
import jax.numpy as jnp

def pairwise_distances(points):
    """
    Calculates the pairwise distances between a set of points.
    
    Args:
        points: an array of shape (n_points, n_dims) containing the coordinates of the points
        
    Returns:
        dists: an array of shape (n_points, n_points) containing the pairwise distances between the points
    """
    n_dims, n_points = points.shape
    tiled_points = jnp.tile(points, (1, n_points, 1))
    transposed_points = jnp.transpose(tiled_points, axes=(0, 2, 1))
    diffs = tiled_points - transposed_points
    return diffs


# def measure_of_spread(points):
#     """
#     Calculates a measure of spread for a set of points.

#     Args:
#         points: an array of shape (n_points, n_dims) containing the coordinates of the points

#     Returns:
#         spread: a scalar value indicating the spread of the points
#     """
#     dists = pairwise_distances(points)
#     cov = -0.5 * jnp.square(dists)
#     eigvals = jnp.linalg.eigvalsh(cov)
#     spread = jnp.sum(jnp.sqrt(jnp.maximum(eigvals, 0.)))
#     return spread

def measure_of_spread(points):
    """
    Calculates a measure of spread for a set of points.

    Args:
        points: an array of shape (n_points, n_dims) containing the coordinates of the points

    Returns:
        spread: a scalar value indicating the spread of the points
    """
    dists = jnp.abs(jnp.subtract(points, points.T))
    cov = jnp.cov(dists.squeeze(), rowvar=False)
    eigvals = jnp.linalg.eigvalsh(cov)
    spread = jnp.sum(jnp.sqrt(jnp.maximum(eigvals, 0.)))
    return spread

array = jnp.array([[-5., -2.5, 0., 2.5, 5.]])

# %%
import jax

dists = jnp.abs(pairwise_distances(array))
print(dists.squeeze().shape)
cov = jnp.cov(dists.squeeze()) #, rowvar=False)
print(cov)
eigvals = jnp.linalg.eigvalsh(cov)
print(eigvals)
spread = jnp.sum(jnp.sqrt(jnp.maximum(eigvals, 0.)))
print(spread)
jax.value_and_grad(measure_of_spread)(array)
# Out:
# (5, 5)
# [[ 15.625   9.375   0.     -9.375 -15.625]
#  [  9.375   8.125   2.5    -4.375  -9.375]
#  [  0.      2.5     4.375   2.5     0.   ]
#  [ -9.375  -4.375   2.5     8.125   9.375]
#  [-15.625  -9.375   0.      9.375  15.625]]
# [4.3331872e-07 5.1318276e-01 9.1186106e-01 7.6118164e+00 4.2838135e+01]
# 10.975977
# (DeviceArray(10.975977, dtype=float32),
#  DeviceArray([[-9.7341973e-01, -2.4822432e-01, -2.3841858e-07,
#                 2.4822491e-01,  9.7341949e-01]], dtype=float32))

# %%
array
# Out:
# DeviceArray([[-5. , -2.5,  0. ,  2.5,  5. ]], dtype=float32)

# %%
jax.value_and_grad(measure_of_spread)(array)
# Out:
# (DeviceArray(10.975977, dtype=float32),
#  DeviceArray([[-9.7341973e-01, -2.4822432e-01, -2.3841858e-07,
#                 2.4822491e-01,  9.7341949e-01]], dtype=float32))

# %%
jnp.mean(jnp.abs(pairwise_distances(array)))
# Out:
# DeviceArray(4., dtype=float32)

# %%
def pairwise_distances(points):
    """
    Calculates the pairwise distances between a set of points.
    
    Args:
        points: an array of shape (n_points, n_dims) containing the coordinates of the points
        
    Returns:
        dists: an array of shape (n_points, n_points) containing the pairwise distances between the points
    """
    diffs = points[:, None, :] - points[None, :, :]
    print(diffs)
    squared_distances = jnp.sum(jnp.square(diffs), axis=-1)
    dists = jnp.sqrt(jnp.asarray(squared_distances))
    return dists

pairwise_distances(array)
# Out:
# [[[0. 0. 0. 0. 0.]]]
# DeviceArray([[0.]], dtype=float32)

# %%
abs(jnp.subtract(array, array.T))
# Out:
# DeviceArray([[ 0. ,  2.5,  5. ,  7.5, 10. ],
#              [ 2.5,  0. ,  2.5,  5. ,  7.5],
#              [ 5. ,  2.5,  0. ,  2.5,  5. ],
#              [ 7.5,  5. ,  2.5,  0. ,  2.5],
#              [10. ,  7.5,  5. ,  2.5,  0. ]], dtype=float32)
