# %%
import wandb
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

api = wandb.Api()
runs = api.runs("vz_uci/lfiax1D_linReg_ICML2")

# %%
runs = api.runs("vz_uci/lfiax1D_linReg_ICML2")

# Create an empty list to store the EIG data for each run
eig_data = []

# Iterate through each run and extract the EIG data
for run in runs:
    # Get the history data for the run
    run_data = run.history()
    
    # Extract the EIG column and append it to the list
    eig_col = run_data["EIG"]
    eig_data.append(eig_col)

# Concatenate the EIG data for all runs into a single DataFrame
eig_df = pd.concat(eig_data, axis=1)

# Compute the mean and standard deviation of the EIG values across all runs
eig_mean = eig_df.mean(axis=1)
eig_std = eig_df.std(axis=1)

# %%
runs = api.runs("vz_uci/lfiax10D_linReg_ICML")

# Create an empty list to store the EIG data for each run
eig_data_10D = []

# Iterate through each run and extract the EIG data
for run in runs:
    # Get the history data for the run
    run_data = run.history()
    
    # Extract the EIG column and append it to the list
    eig_col = run_data["EIG"]
    eig_data_10D.append(eig_col)

# Concatenate the EIG data for all runs into a single DataFrame
eig_df_10D = pd.concat(eig_data_10D, axis=1)

# Compute the mean and standard deviation of the EIG values across all runs
eig_mean_10D = eig_df_10D.mean(axis=1)
eig_std_10D = eig_df_10D.std(axis=1)

# %%
runs = api.runs("vz_uci/lfiax100D_linReg_ICML")

# Create an empty list to store the EIG data for each run
eig_data_100D = []

# Iterate through each run and extract the EIG data
for run in runs[:10]:
    # Get the history data for the run
    run_data = run.history()
    
    # Extract the EIG column and append it to the list
    eig_col = run_data["EIG"]
    eig_data_100D.append(eig_col)

# Concatenate the EIG data for all runs into a single DataFrame
eig_df_100D = pd.concat(eig_data_100D, axis=1)

# Compute the mean and standard deviation of the EIG values across all runs
eig_mean_100D = eig_df_100D.mean(axis=1)
eig_std_100D = eig_df_100D.std(axis=1)

# %%
xaxey = np.arange(0, 10000, 20)

fig, ax = plt.subplots()
ax.plot(xaxey, eig_mean.values, label="1D EIG")
ax.plot(xaxey, eig_mean_10D.values, label="10D EIG")
ax.plot(xaxey, eig_mean_100D.values, label="100D EIG")
ax.fill_between(xaxey, eig_mean.values - eig_std.values, eig_mean.values + eig_std.values, alpha=0.3)
ax.fill_between(xaxey, eig_mean_10D.values - eig_std_10D.values, eig_mean_10D.values + eig_std_10D.values, alpha=0.5)
ax.fill_between(xaxey, eig_mean_100D.values - eig_std_100D.values, eig_mean_100D.values + eig_std_100D.values, alpha=0.3)
ax.set_xlabel("Training Step", fontsize=12)
ax.set_ylabel("Mutual Information (EIG)", fontsize=12)
ax.set_title("Aggregate EIG Data Across Runs", fontsize=14)
ax.axhline(y=1.17, linestyle="--", label="1D Reference")
ax.legend()
ax.set_ylim(0., 8.)
ax.set_xlim(0., 10000)

fig.savefig("lin_reg_MI.svg", format="svg")

plt.show()

# %% [markdown]
# ## Getting optimal experimental designs

# %%
runs = api.runs("vz_uci/lfiax1D_linReg_ICML2")

# Create an empty list to store the EIG data for each run
xi_data_1D = []

# Iterate through each run and extract the EIG data
for run in runs:
    # Get the history data for the run
    run_data = run.history()
    
    # Extract the EIG column and append it to the list
    xi_col = run_data["xi"]
    xi_data_1D.append(xi_col)

# Concatenate the EIG data for all runs into a single DataFrame
xi_df_1D = pd.concat(xi_data_1D, axis=1)

# Compute the mean and standard deviation of the EIG values across all runs
# xi_mean_100D = xi_df_100D.mean(axis=1)
# xi_std_100D = xi_df_100D.std(axis=1)

# %%
plt.plot(xi_df_1D.iloc[:,2])

# %%
# plot each column as its own line
fig, ax = plt.subplots()
for col in xi_df_1D.columns:
    ax.plot(xaxey, xi_df_1D[col], linewidth=1, alpha=0.3)

# set plot title, legend, and axis labels
ax.set_title('My Plot')
ax.legend()
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_xlim(0., 10000)

# show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
runs = api.runs("vz_uci/lfiax1D_linReg_ICML2")

# Create an empty list to store the EIG data for each run
xi_data_1D = []

# Iterate through each run and extract the EIG data
for run in runs[:10]:
    # Get the history data for the run
    run_data = run.history()
    
    # Extract the EIG column and append it to the list
    xi_col = run_data["xi"]
    xi_data_1D.append(xi_col)

# Concatenate the EIG data for all runs into a single DataFrame
xi_df_1D = pd.concat(xi_data_1D, axis=1)

# %%
# plot each column as its own line
fig, ax = plt.subplots()
for col in xi_df_1D.columns:
    ax.plot(xaxey, xi_df_1D[col], label=col)

# set plot title, legend, and axis labels
ax.set_title('My Plot')
# ax.legend()
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')

# show the plot
plt.show()

# %%
runs = api.runs("vz_uci/lfiax10D_linReg_ICML")

# Create an empty list to store the EIG data for each run
xi_data_10D = []

# Iterate through each run and extract the EIG data
for run in runs[:10]:
    # Get the history data for the run
    run_data = run.history()
    
    # Extract the EIG column and append it to the list
    xi_col = run_data["xi"]
    xi_data_10D.append(xi_col)

# Concatenate the EIG data for all runs into a single DataFrame
xi_df_10D = pd.concat(xi_data_10D, axis=1)

# %%
# create a figure and axis object
fig, ax = plt.subplots()

xaxey = np.arange(0, 10000, 20)

# loop through each dimension of the array and plot it as a line
for i in range(10):
    ax.plot(xaxey, xi_df_10D.iloc[:,4].apply(lambda x: x[i]), color='blue', alpha=0.5)

# set plot title, legend, and axis labels
ax.set_title('10D Linear Regression Design Optimization', fontsize=15)
# ax.legend(range(1, 11))
ax.set_xlabel('Training Step', fontsize=12)
ax.set_ylabel('Xi Value', fontsize=12)
ax.set_ylim(-10., 10.)
ax.set_xlim(0., 10000.)

fig.savefig("10D_designs.svg", format="svg")

# show the plot
plt.show()

# %%
runs = api.runs("vz_uci/lfiax100D_linReg_ICML")

# Create an empty list to store the EIG data for each run
xi_data_100D = []

# Iterate through each run and extract the EIG data
for run in runs[:10]:
    # Get the history data for the run
    run_data = run.history()
    
    # Extract the EIG column and append it to the list
    xi_col = run_data["xi"]
    xi_data_100D.append(xi_col)

# Concatenate the EIG data for all runs into a single DataFrame
xi_df_100D = pd.concat(xi_data_100D, axis=1)

# Compute the mean and standard deviation of the EIG values across all runs
# xi_mean_100D = xi_df_100D.mean(axis=1)
# xi_std_100D = xi_df_100D.std(axis=1)

# %%
xi_df_100D
# Out:
#                                                     xi  \
# 0    {'packedBins': {'min': -8.453924179077148, 'si...
# 1    {'packedBins': {'min': -8.570009231567383, 'si...
# 2    {'_type': 'histogram', 'values': [1, 2, 0, 1, ...
# 3    {'packedBins': {'size': 0.5310825705528259, 'c...
# 4    {'packedBins': {'min': -8.771974563598633, 'si...
# ..                                                 ...
# 495  {'packedBins': {'min': -8.53394889831543, 'siz...
# 496  {'packedBins': {'min': -9.363754272460938, 'si...
# 497  {'packedBins': {'count': 32, 'min': -8.3400697...
# 498  {'packedBins': {'min': -8.626035690307617, 'si...
# 499  {'packedBins': {'size': 0.5246331244707108, 'c...
#
#                                                     xi  \
# 0    {'_type': 'histogram', 'values': [1, 1, 1, 0, ...
# 1    {'_type': 'histogram', 'values': [1, 1, 1, 0, ...
# 2    {'packedBins': {'size': 0.5312613248825073, 'c...
# 3    {'_type': 'histogram', 'values': [1, 0, 2, 1, ...
# 4    {'_type': 'histogram', 'values': [1, 1, 1, 0, ...
# ..                                                 ...
# 495  {'_type': 'histogram', 'values': [1, 0, 0, 3, ...
# 496  {'_type': 'histogram', 'values': [1, 0, 2, 0, ...
# 497  {'values': [1, 1, 1, 0, 0, 2, 3, 0, 2, 0, 2, 3...
# 498  {'_type': 'histogram', 'values': [1, 1, 4, 1, ...
# 499  {'_type': 'histogram', 'values': [1, 0, 0, 3, ...
#
#                                                     xi  \
# 0    {'values': [1, 2, 1, 1, 1, 2, 2, 2, 1, 0, 0, 0...
# 1    {'_type': 'histogram', 'values': [2, 1, 1, 1, ...
# 2    {'values': [1, 2, 1, 2, 0, 2, 2, 2, 1, 0, 0, 0...
# 3    {'values': [1, 2, 1, 2, 0, 2, 3, 1, 1, 0, 0, 2...
# 4    {'values': [2, 1, 1, 1, 2, 1, 4, 0, 1, 0, 0, 2...
# ..                                                 ...
# 495  {'values': [3, 4, 1, 1, 4, 2, 4, 2, 2, 2, 0, 1...
# 496  {'_type': 'histogram', 'values': [2, 1, 1, 1, ...
# 497  {'packedBins': {'min': -9.897103309631348, 'si...
# 498  {'values': [1, 2, 1, 1, 1, 2, 2, 2, 1, 0, 0, 0...
# 499  {'_type': 'histogram', 'values': [3, 4, 1, 1, ...
#
#                                                     xi  \
# 0    {'_type': 'histogram', 'values': [7, 8, 0, 6, ...
# 1    {'_type': 'histogram', 'values': [8, 7, 0, 6, ...
# 2    {'_type': 'histogram', 'values': [7, 0, 2, 4, ...
# 3    {'values': [3, 1, 3, 1, 5, 2, 2, 2, 4, 1, 2, 3...
# 4    {'_type': 'histogram', 'values': [3, 1, 3, 3, ...
# ..                                                 ...
# 495  {'_type': 'histogram', 'values': [3, 3, 1, 3, ...
# 496  {'_type': 'histogram', 'values': [5, 3, 1, 4, ...
# 497  {'_type': 'histogram', 'values': [4, 1, 3, 3, ...
# 498  {'_type': 'histogram', 'values': [4, 1, 3, 2, ...
# 499  {'_type': 'histogram', 'values': [4, 1, 2, 3, ...
#
#                                                     xi  \
# 0    {'packedBins': {'min': -9.889829635620117, 'si...
# 1    {'packedBins': {'size': 0.5639315545558929, 'c...
# 2    {'packedBins': {'min': -9.866289138793945, 'si...
# 3    {'values': [1, 0, 0, 1, 2, 1, 2, 2, 3, 1, 0, 3...
# 4    {'_type': 'histogram', 'values': [4, 3, 4, 1, ...
# ..                                                 ...
# 495  {'values': [3, 2, 1, 1, 3, 3, 3, 4, 5, 3, 2, 5...
# 496  {'packedBins': {'min': -9.867709159851074, 'si...
# 497  {'packedBins': {'count': 32, 'min': -9.8908185...
# 498  {'packedBins': {'min': -9.32906723022461, 'siz...
# 499  {'packedBins': {'min': -9.494251251220703, 'si...
#
#                                                     xi  \
# 0    {'_type': 'histogram', 'values': [1, 1, 0, 0, ...
# 1    {'_type': 'histogram', 'values': [2, 3, 0, 2, ...
# 2    {'values': [1, 1, 0, 0, 1, 1, 1, 3, 1, 1, 1, 3...
# 3    {'_type': 'histogram', 'values': [2, 0, 0, 0, ...
# 4    {'_type': 'histogram', 'values': [2, 0, 0, 0, ...
# ..                                                 ...
# 495  {'_type': 'histogram', 'values': [2, 0, 0, 1, ...
# 496  {'_type': 'histogram', 'values': [1, 1, 0, 0, ...
# 497  {'_type': 'histogram', 'values': [2, 0, 0, 0, ...
# 498  {'_type': 'histogram', 'values': [2, 0, 0, 0, ...
# 499  {'_type': 'histogram', 'values': [2, 0, 0, 0, ...
#
#                                                     xi  \
# 0    {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
# 1    {'_type': 'histogram', 'values': [1, 0, 1, 1, ...
# 2    {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
# 3    {'_type': 'histogram', 'values': [3, 2, 3, 2, ...
# 4    {'_type': 'histogram', 'values': [1, 1, 1, 0, ...
# ..                                                 ...
# 495  {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
# 496  {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
# 497  {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
# 498  {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
# 499  {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
#
#                                                     xi  \
# 0    {'_type': 'histogram', 'values': [1, 0, 0, 4, ...
# 1    {'_type': 'histogram', 'values': [1, 0, 4, 1, ...
# 2    {'_type': 'histogram', 'values': [1, 0, 2, 3, ...
# 3    {'_type': 'histogram', 'values': [3, 6, 2, 3, ...
# 4    {'_type': 'histogram', 'values': [1, 0, 0, 2, ...
# ..                                                 ...
# 495  {'packedBins': {'min': -9.563039779663086, 'si...
# 496  {'_type': 'histogram', 'values': [1, 1, 3, 1, ...
# 497  {'values': [1, 1, 3, 1, 3, 5, 0, 0, 1, 3, 2, 2...
# 498  {'values': [1, 0, 2, 3, 0, 0, 2, 1, 1, 2, 2, 4...
# 499  {'_type': 'histogram', 'values': [1, 0, 3, 2, ...
#
#                                                     xi  \
# 0    {'values': [1, 0, 0, 0, 2, 0, 1, 1, 2, 2, 4, 1...
# 1    {'_type': 'histogram', 'values': [1, 0, 0, 2, ...
# 2    {'_type': 'histogram', 'values': [4, 1, 3, 5, ...
# 3    {'_type': 'histogram', 'values': [1, 0, 0, 0, ...
# 4    {'_type': 'histogram', 'values': [1, 3, 1, 6, ...
# ..                                                 ...
# 495  {'_type': 'histogram', 'values': [1, 0, 0, 2, ...
# 496  {'packedBins': {'min': -9.698029518127441, 'si...
# 497  {'_type': 'histogram', 'values': [1, 0, 0, 1, ...
# 498  {'_type': 'histogram', 'values': [2, 0, 1, 2, ...
# 499  {'_type': 'histogram', 'values': [1, 1, 1, 1, ...
#
#                                                     xi
# 0    {'_type': 'histogram', 'values': [1, 1, 6, 6, ...
# 1    {'_type': 'histogram', 'values': [1, 0, 3, 3, ...
# 2    {'packedBins': {'min': -7.953723907470703, 'si...
# 3    {'_type': 'histogram', 'values': [1, 1, 0, 3, ...
# 4    {'_type': 'histogram', 'values': [2, 0, 0, 1, ...
# ..                                                 ...
# 495  {'_type': 'histogram', 'values': [1, 0, 2, 5, ...
# 496  {'_type': 'histogram', 'values': [2, 0, 0, 1, ...
# 497  {'_type': 'histogram', 'values': [1, 1, 1, 1, ...
# 498  {'_type': 'histogram', 'values': [2, 0, 0, 1, ...
# 499  {'packedBins': {'min': -8.448593139648438, 'si...
#
# [500 rows x 10 columns]

# %%
xi_df_100D.iloc[1]
# Out:
# xi    {'packedBins': {'min': -8.570009231567383, 'si...
# xi    {'_type': 'histogram', 'values': [1, 1, 1, 0, ...
# xi    {'_type': 'histogram', 'values': [2, 1, 1, 1, ...
# xi    {'_type': 'histogram', 'values': [8, 7, 0, 6, ...
# xi    {'packedBins': {'size': 0.5639315545558929, 'c...
# xi    {'_type': 'histogram', 'values': [2, 3, 0, 2, ...
# xi    {'_type': 'histogram', 'values': [1, 0, 1, 1, ...
# xi    {'_type': 'histogram', 'values': [1, 0, 4, 1, ...
# xi    {'_type': 'histogram', 'values': [1, 0, 0, 2, ...
# xi    {'_type': 'histogram', 'values': [1, 0, 3, 3, ...
# Name: 1, dtype: object

# %%
run_data.xi[0].keys()
# Out:
# dict_keys(['_type', 'values', 'packedBins'])

# %%
run_data
# Out:
#          loss  _step   kl_divs     _runtime  xi_grads    _timestamp        xi  \
# 0    0.329029   5635  1.310685  1061.072839 -0.005762  1.682364e+09 -8.110025
# 1    0.405720   2034  1.595381   421.066314  0.043906  1.682364e+09 -0.132085
# 2    0.357836   3563  1.370827   692.785288  0.005328  1.682364e+09 -7.582026
# 3    0.210837   9593  1.307981  1764.437738 -0.037860  1.682365e+09 -9.560005
# 4    0.235576   6583  1.645184  1229.572657  0.085795  1.682364e+09 -9.260010
# ..        ...    ...       ...          ...       ...           ...       ...
# 495  0.385578   2064  1.301903   426.398474  0.047546  1.682364e+09 -0.192085
# 496  0.398314   2506  1.071185   504.974810  0.088440  1.682364e+09 -1.712086
# 497  0.074360   5348  1.468476  1009.994226 -0.017349  1.682364e+09 -8.540019
# 498  0.024825   8571  1.677687  1582.854392  0.011372  1.682365e+09 -9.990000
# 499  0.300191   7056  1.604425  1313.621353  0.022481  1.682364e+09 -9.130009
#
#           EIG
# 0    0.615077
# 1    0.614726
# 2    0.685022
# 3    0.758192
# 4    0.787959
# ..        ...
# 495  0.685297
# 496  0.626583
# 497  0.985540
# 498  0.994307
# 499  0.693769
#
# [500 rows x 8 columns]

# %%
type(run_data)
# Out:
# pandas.core.frame.DataFrame

# %%
project_name = "lfiax1D_linReg_ICML2"

run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        data = file.download(root="./downloads/")
        # print(dir(run_data))
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     130 try:
# --> 131     result = self._call_fn(*args, **kwargs)
#     132     # Only print resolved attempts once every minute
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:2818, in File.download(self, root, replace, exist_ok)
#    2817     else:
# -> 2818         raise ValueError(
#    2819             "File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error."
#    2820         )
#    2822 util.download_file_from_url(path, self.url, Api().api_key)
#
# ValueError: File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error.
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# /Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb Cell 2 in 9
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> for run in runs:
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>     for file in run.files():
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>         # if file.type == "metadata":
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>         #     # Skip metadata files
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>         #     continue
# ----> <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>         data = file.download(root="./downloads/")
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a>         # print(dir(run_data))
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>         run_data.append({
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>             "run_id": run.id,
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a>             "file_name": file.name,
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a>             "file_data": data,
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a>         })
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:87, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      85     raise
#      86 else:
# ---> 87     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:2818, in File.download(self, root, replace, exist_ok)
#    2816         return open(path)
#    2817     else:
# -> 2818         raise ValueError(
#    2819             "File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error."
#    2820         )
#    2822 util.download_file_from_url(path, self.url, Api().api_key)
#    2823 return open(path)
#
# CommError: File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error.

# %%
# Download all the files for each run
run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        file_path = f"./downloads/{file.name}"
        if os.path.exists(file_path):
            # File already exists, skip downloading it
            continue
        try:
            data = file.download(root="./downloads/")
        except wandb.CommError as e:
            if "File already exists" in str(e):
                # File already exists, skip downloading it
                continue
            else:
                raise e
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })

# %%
len(run_data)
# Out:
# 0

# %%
import pandas as pd

df = pd.DataFrame(run_data)

# %%
df
# Out:
#      run_id                               file_name  \
# 0  mt4ggpy3  artifact/432430672/wandb_manifest.json
# 1  j79z7dzq  artifact/432430674/wandb_manifest.json
# 2  hre4ge9v  artifact/432430677/wandb_manifest.json
# 3  encxkvir  artifact/432430679/wandb_manifest.json
# 4  d50vwwxo  artifact/432430693/wandb_manifest.json
# 5  bip9xs0w  artifact/432430675/wandb_manifest.json
# 6  a5c5dbat  artifact/432430673/wandb_manifest.json
# 7  u47396to  artifact/432425570/wandb_manifest.json
# 8  u47396to  artifact/432430676/wandb_manifest.json
# 9  rl2sfg3l  artifact/432430671/wandb_manifest.json
#
#                                            file_data
# 0  <_io.TextIOWrapper name='./downloads/artifact/...
# 1  <_io.TextIOWrapper name='./downloads/artifact/...
# 2  <_io.TextIOWrapper name='./downloads/artifact/...
# 3  <_io.TextIOWrapper name='./downloads/artifact/...
# 4  <_io.TextIOWrapper name='./downloads/artifact/...
# 5  <_io.TextIOWrapper name='./downloads/artifact/...
# 6  <_io.TextIOWrapper name='./downloads/artifact/...
# 7  <_io.TextIOWrapper name='./downloads/artifact/...
# 8  <_io.TextIOWrapper name='./downloads/artifact/...
# 9  <_io.TextIOWrapper name='./downloads/artifact/...

# %%
# Extract the "xi" data from the log files
xi_data = pd.DataFrame()
for index, row in df.iterrows():
    # Split the log file into lines
    lines = row["log_data"].split("\n")
    for line in lines:
        # Check if the line contains "xi"
        if "xi" in line:
            # Extract the "xi" value from the line
            xi_value = line.split(" ")[-1]
            # Add the "xi" value to the DataFrame
            xi_data.loc[row["run_id"], len(xi_data.columns)] = float(xi_value)

# Print the "xi" data
print(xi_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'log_data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb Cell 9 in 5
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> xi_data = pd.DataFrame()
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> for index, row in df.iterrows():
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     # Split the log file into lines
# ----> <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     lines = row["log_data"].split("\n")
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     for line in lines:
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>         # Check if the line contains "xi"
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>         if "xi" in line:
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>             # Extract the "xi" value from the line
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'log_data'

# %%
run_data = []
for run in runs:
    log_file = None
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        if file.name.endswith(".log"):
            # Save the path to the log file
            log_file = file.name
        # Download the file to the destination folder
        file.download(root="./downloads", exist_ok=True)
    if log_file is not None:
        # Read the contents of the log file into a Pandas DataFrame
        log_path = os.path.join("./downloads", log_file)
        log_data = pd.read_csv(log_path, delimiter="\t", names=["step", "key", "value"])
        xi_data = log_data[log_data["key"] == "xi"]
        xi_data = xi_data.drop(["key"], axis=1)
        xi_data = xi_data.rename(columns={"value": run.id})
        xi_data.set_index("step", inplace=True)
        run_data.append(xi_data)

# Concatenate the "xi" data from all runs into a single DataFrame
xi_data = pd.concat(run_data, axis=1)
runs_list = xi_data.columns.tolist()

# Print the "xi" data
print(xi_data)
# Out:
# Empty DataFrame
# Columns: [yts7jssv, mt4ggpy3, j79z7dzq, hre4ge9v, encxkvir, d50vwwxo, bip9xs0w, a5c5dbat, u47396to, rl2sfg3l]
# Index: []

# %%
xi_data.columns.tolist()
# Out:
# ['yts7jssv',
#  'mt4ggpy3',
#  'j79z7dzq',
#  'hre4ge9v',
#  'encxkvir',
#  'd50vwwxo',
#  'bip9xs0w',
#  'a5c5dbat',
#  'u47396to',
#  'rl2sfg3l']

# %%
api = wandb.Api()

# List of runs (run IDs)
runs_list = xi_data.columns.tolist()

# Dictionary to store the data for each run
data_dict = {}

# Loop over the runs and get the data for each run
for run_id in runs_list:
    # Get the run object
    run = api.run(run_id)
    
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

# Combine the data for all runs into a single dataframe
df = pd.concat(data_dict.values(), keys=data_dict.keys(), names=["run_id", "step"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:880, in Api.run(self, path)
#     879 if not self._runs.get(path):
# --> 880     self._runs[path] = Run(self.client, entity, project, run_id)
#     881 return self._runs[path]
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1720, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1718 self._state = _attrs.get("state", "not found")
# -> 1720 self.load(force=not _attrs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1824, in Run.load(self, force)
#    1819 if (
#    1820     response is None
#    1821     or response.get("project") is None
#    1822     or response["project"].get("run") is None
#    1823 ):
# -> 1824     raise ValueError("Could not find run %s" % self)
#    1825 self._attrs = response["project"]["run"]
#
# ValueError: Could not find run <Run vz_uci/yts7jssv/yts7jssv (not found)>
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# /Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb Cell 12 in 1
#       <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> # Loop over the runs and get the data for each run
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> for run_id in runs_list:
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>     # Get the run object
# ---> <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a>     run = api.run(run_id)
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a>     # Get the data associated with the "xi" key
#      <a href='vscode-notebook-cell:/Users/vincent_zaballa/Development/lfiax/examples/linear_regression_analysis.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a>     xi_data = run.history(keys=["xi"])
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:87, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      85     raise
#      86 else:
# ---> 87     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:880, in Api.run(self, path)
#     878 entity, project, run_id = self._parse_path(path)
#     879 if not self._runs.get(path):
# --> 880     self._runs[path] = Run(self.client, entity, project, run_id)
#     881 return self._runs[path]
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1720, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1717 self._summary = None
#    1718 self._state = _attrs.get("state", "not found")
# -> 1720 self.load(force=not _attrs)
#
# File ~/anaconda3/envs/sdm3/lib/python3.9/site-packages/wandb/apis/public.py:1824, in Run.load(self, force)
#    1818 response = self._exec(query)
#    1819 if (
#    1820     response is None
#    1821     or response.get("project") is None
#    1822     or response["project"].get("run") is None
#    1823 ):
# -> 1824     raise ValueError("Could not find run %s" % self)
#    1825 self._attrs = response["project"]["run"]
#    1826 self._state = self._attrs["state"]
#
# CommError: Could not find run <Run vz_uci/yts7jssv/yts7jssv (not found)>

# %%
entity = "vz_uci"
project = "lfiax1D_linReg_ICML2"

for run_id in runs_list:
    run = api.run(f"{entity}/{project}/{run_id}")
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

# %%
data_dict['yts7jssv'].shape
# Out:
# (500, 2)

# %%
len(xi_data)
# Out:
# 500

# %% [markdown]
# Moose

# %%
data_dict['yts7jssv']
# Out:
#      _step         xi
# 0     7556   3.520075
# 1     2135   9.990000
# 2     1052   9.760003
# 3     2302   9.940001
# 4     1041   9.790003
# ..     ...        ...
# 495   2496  10.000000
# 496   7483   3.870070
# 497   1325  10.000000
# 498   7459   3.990068
# 499   7414   4.220065
#
# [500 rows x 2 columns]

# %%
from itertools import islice
import matplotlib.pyplot as plt
import numpy as np

# Create a new dictionary that only contains the first 10 items of data_dict
last_10_items = dict(list(data_dict.items())[-10:])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(last_10_items.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
last_five = {k: v[-1:] for k, v in data_dict.items()}
last_five
# Out:
# {'vti9vucv':      _step                           xi
#  499   9993  [[NaN, NaN, NaN, NaN, NaN]],
#  'qcfm7w12':      _step                                                 xi
#  499   9988  [[-1.3005709648132324, -2.1989569664001465, -0...,
#  '928mx08q':      _step                           xi
#  499   9983  [[NaN, NaN, NaN, NaN, NaN]],
#  'zfdpm9ye':      _step                                                 xi
#  499   9990  [[-5.001311302185059, 10, 9.2000093460083, 9.1...,
#  'wd3be2nt':      _step                                                 xi
#  499   9952  [[-2.2002625465393066, 0.3990784287452698, 3.7...,
#  'uroq913x':      _step                                                 xi
#  499   9931  [[-8.799710273742676, 0.8632327914237976, 0.09...,
#  'uq05hd62':      _step                           xi
#  499   9992  [[NaN, NaN, NaN, NaN, NaN]],
#  'mxilke43':      _step                           xi
#  499   9997  [[NaN, NaN, NaN, NaN, NaN]],
#  'k81862ba':      _step                           xi
#  499   9998  [[NaN, NaN, NaN, NaN, NaN]],
#  'hkotq2bc':      _step                           xi
#  499   9984  [[NaN, NaN, NaN, NaN, NaN]],
#  'drffv8ls':      _step                           xi
#  499   9977  [[NaN, NaN, NaN, NaN, NaN]],
#  'do6dfs77':      _step                                                 xi
#  499   9960  [[-9.000046730041504, 8.799894332885742, -9.29...,
#  'dc4brjqn':      _step                                                 xi
#  499   9982  [[-1.2004597187042236, -1.3998961448669434, 5....,
#  '91rovnay':      _step                           xi
#  499   9998  [[NaN, NaN, NaN, NaN, NaN]],
#  '62682s91':      _step                           xi
#  499   9989  [[NaN, NaN, NaN, NaN, NaN]],
#  '5ydy3oon':      _step                           xi
#  499   9999  [[NaN, NaN, NaN, NaN, NaN]],
#  '55z8tajj':      _step                           xi
#  499   9951  [[NaN, NaN, NaN, NaN, NaN]],
#  '4h5bnhzq':      _step                                                 xi
#  499   9966  [[-4.60032844543457, 1.099918007850647, -1.401...,
#  '1z8v8ma6':      _step                                                 xi
#  499   9994  [[-5.400033950805664, -9.50008773803711, 9.199...,
#  '1yf683j7':      _step                           xi
#  499   9935  [[NaN, NaN, NaN, NaN, NaN]],
#  '1cfjacq8':      _step                                                 xi
#  499   9989  [[2.899975538253784, -6.5002546310424805, 6.90...,
#  'ab2yi2rc':      _step                                                 xi
#  499   9997  [[-0.9000678062438965, -0.08400087803602219, 5...,
#  '2ua46uq4':      _step                                                 xi
#  499   9996  [[-9.80000114440918, -5.8006367683410645, -0.9...}

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Run")
ax.set_ylabel("Xi Value")
ax.set_title("Final Xi Value for Each Run")

# Get the last xi value for each run
last_xi_values = {}
for run, xi_data in data_dict.items():
    last_xi_values[run] = xi_data.iloc[-1]["xi"]

# Plot the last xi values as a bar chart
colors = plt.cm.tab20(np.linspace(0, 1, len(last_xi_values)))
x_ticks = range(len(last_xi_values))
for i, (run, xi_values) in enumerate(last_xi_values.items()):
    ax.bar(i, xi_values[-1], color=colors[i], label=f"Run {run}")

# Set the x-ticks to the run names
ax.set_xticks(x_ticks)
ax.set_xticklabels(last_xi_values.keys())

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Plot the last xi value for each run that doesn't have NaN values
fig, ax = plt.subplots()
ax.set_xlabel("Run")
ax.set_ylabel("Xi Value")
ax.set_title("Final Xi Value for Each Run")

# Keep track of the color index for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))

# Keep track of the x position for each bar
x_pos = []

for i, (run, xi_data) in enumerate(data_dict.items()):
    # Check if the xi array for this run has any NaN values
    # if not np.isnan(xi_data.iloc[-1]["xi"]).any():
    # Get the last xi value for this run
    xi_values = xi_data.iloc[-1]["xi"]
    # Add the bar to the plot
    for j, xi_value in enumerate(xi_values):
        ax.bar(i, xi_value, color=colors[i], label=f"Run {run} ({j+1})")
    x_pos.append(i)

# Set the x-axis labels and limits
ax.set_xticks(x_pos)
ax.set_xticklabels([f"Run {run}" for run in data_dict.keys()])
plt.xticks(rotation=45, ha='right')
ax.set_xlim(-0.5, len(x_pos)-0.5)

ax.set_yticks(np.arange(-10, 11, 1))
ax.set_ylim(-10, 10)

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Create a figure and axis for the plot
fig, ax = plt.subplots()
ax.set_xlabel("Run")
ax.set_ylabel("Xi Value")
ax.set_title("Final Xi Values Xi_LR=1e-1")

# Get a list of colors for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))

# Loop through each run and plot the final xi value as a scatter point
for i, (run, xi_data) in enumerate(data_dict.items()):
    # Extract the final xi values from the history data
    xi_values = xi_data.iloc[-1]["xi"]
    # Convert any string values to floats
    xi_values = [float(val) if type(val) == str else val for val in xi_values]
    # Create a list of x-axis values with the same length as xi_values
    x_vals = [i] * len(xi_values[0])
    # Plot the xi value as a scatter point
    ax.scatter(x_vals, xi_values, color=colors[i], label=f"Run {run}")

# Set the x-tick labels to the run names
ax.set_xticks(list(range(len(data_dict))))
ax.set_xticklabels(list(data_dict.keys()), rotation=90)

# Set the y-axis limits and labels
ax.set_ylim(-10, 10)
ax.set_yticks(list(range(-10, 11)))
ax.set_yticklabels(list(range(-10, 11)))

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Create a new dictionary that only contains the first 10 items of data_dict
last_10_items = dict(list(data_dict.items())[-10:])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(last_10_items.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
# Create a new dictionary that only contains the first 10 items of data_dict
last_10_items = dict(list(data_dict.items())[:23])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(last_10_items.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
import wandb

api = wandb.Api()
runs = api.runs("vz_uci/lfiax_5d_stupidAdam")

# Download all the files for each run
run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        file_path = f"./downloads/{file.name}"
        if os.path.exists(file_path):
            # File already exists, skip downloading it
            continue
        try:
            data = file.download(root="./downloads/")
        except wandb.CommError as e:
            if "File already exists" in str(e):
                # File already exists, skip downloading it
                continue
            else:
                raise e
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })

# %%
import pandas as pd

for run in runs:
    log_file = None
    for file in run.files():
        if file.name.endswith(".log"):
            # Save the path to the log file
            log_file = file.name
        # Download the file to the destination folder
        file.download(root="./downloads", exist_ok=True)
    if log_file is not None:
        # Read the contents of the log file into a Pandas DataFrame
        log_path = os.path.join("./downloads", log_file)
        log_data = pd.read_csv(log_path, delimiter="\t", names=["step", "key", "value"])
        xi_data = log_data[log_data["key"] == "xi"]
        xi_data = xi_data.drop(["key"], axis=1)
        xi_data = xi_data.rename(columns={"value": run.id})
        xi_data.set_index("step", inplace=True)
        run_data.append(xi_data)

# Concatenate the "xi" data from all runs into a single DataFrame
xi_data = pd.concat(run_data, axis=1)
runs_list = xi_data.columns.tolist()

# %%
entity = "vz_uci"
project = "lfiax_5d_stupidAdam"

data_dict = {}

for run_id in runs_list:
    run = api.run(f"{entity}/{project}/{run_id}")
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(data_dict.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
import pandas as pd
import wandb

entity = "vz_uci"
project = "lfiax_5d_stupidAdam_designRegularize"

api = wandb.Api()
runs = api.runs(f"{entity}/{project}")

# Download all the files for each run
run_data = []
for run in runs:
    for file in run.files():
        # if file.type == "metadata":
        #     # Skip metadata files
        #     continue
        file_path = f"./downloads/{file.name}"
        if os.path.exists(file_path):
            # File already exists, skip downloading it
            continue
        try:
            data = file.download(root="./downloads/")
        except wandb.CommError as e:
            if "File already exists" in str(e):
                # File already exists, skip downloading it
                continue
            else:
                raise e
        run_data.append({
            "run_id": run.id,
            "file_name": file.name,
            "file_data": data,
        })


for run in runs:
    log_file = None
    for file in run.files():
        if file.name.endswith(".log"):
            # Save the path to the log file
            log_file = file.name
        # Download the file to the destination folder
        file.download(root="./downloads", exist_ok=True)
    if log_file is not None:
        # Read the contents of the log file into a Pandas DataFrame
        log_path = os.path.join("./downloads", log_file)
        log_data = pd.read_csv(log_path, delimiter="\t", names=["step", "key", "value"])
        xi_data = log_data[log_data["key"] == "xi"]
        xi_data = xi_data.drop(["key"], axis=1)
        xi_data = xi_data.rename(columns={"value": run.id})
        xi_data.set_index("step", inplace=True)
        run_data.append(xi_data)

# Concatenate the "xi" data from all runs into a single DataFrame
xi_data = pd.concat(run_data, axis=1)
runs_list = xi_data.columns.tolist()

# %%
import matplotlib.pyplot as plt
import numpy as np

data_dict = {}

for run_id in runs_list:
    run = api.run(f"{entity}/{project}/{run_id}")
    # Get the data associated with the "xi" key
    xi_data = run.history(keys=["xi"])
    # Add the data to the dictionary
    data_dict[run_id] = xi_data

last_10_items = dict(list(data_dict.items())[-10:])

fig, ax = plt.subplots()
ax.set_xlabel("Step")
ax.set_ylabel("Xi Value")
ax.set_title("Xi Value for Each Run")

# Plot the xi data for each run
colors = plt.cm.tab20(np.linspace(0, 1, len(data_dict)))
for i, (run, xi_data) in enumerate(data_dict.items()):
    # Get the xi values as a 2-dimensional array
    xi_values = xi_data["xi"].values
    xi_values = np.vstack(xi_values)
    # xi_values = np.array([float(val) if isinstance(val, str) else val for val in xi_values[0]])
    xi_values = np.array([[float(val) if isinstance(val, str) else val for val in row] for row in xi_values])
    
    # Transpose the array so each of the 5 values is in a separate row
    xi_values = xi_values.T
    # Loop through each of the 5 values and plot a separate line for each
    for j in range(xi_values.shape[0]):
        steps = list(range(len(xi_values[j])))
        ax.plot(steps, xi_values[j], color=colors[i], label=f"Run {run} ({j+1})")

# Add legend and show the plot
# ax.legend()
plt.show()

# %%
import jax.numpy as jnp

def pairwise_distances(points):
    """
    Calculates the pairwise distances between a set of points.
    
    Args:
        points: an array of shape (n_points, n_dims) containing the coordinates of the points
        
    Returns:
        dists: an array of shape (n_points, n_points) containing the pairwise distances between the points
    """
    n_dims, n_points = points.shape
    tiled_points = jnp.tile(points, (1, n_points, 1))
    transposed_points = jnp.transpose(tiled_points, axes=(0, 2, 1))
    diffs = tiled_points - transposed_points
    return diffs


# def measure_of_spread(points):
#     """
#     Calculates a measure of spread for a set of points.

#     Args:
#         points: an array of shape (n_points, n_dims) containing the coordinates of the points

#     Returns:
#         spread: a scalar value indicating the spread of the points
#     """
#     dists = pairwise_distances(points)
#     cov = -0.5 * jnp.square(dists)
#     eigvals = jnp.linalg.eigvalsh(cov)
#     spread = jnp.sum(jnp.sqrt(jnp.maximum(eigvals, 0.)))
#     return spread

def measure_of_spread(points):
    """
    Calculates a measure of spread for a set of points.

    Args:
        points: an array of shape (n_points, n_dims) containing the coordinates of the points

    Returns:
        spread: a scalar value indicating the spread of the points
    """
    dists = jnp.abs(jnp.subtract(points, points.T))
    cov = jnp.cov(dists.squeeze(), rowvar=False)
    eigvals = jnp.linalg.eigvalsh(cov)
    spread = jnp.sum(jnp.sqrt(jnp.maximum(eigvals, 0.)))
    return spread

array = jnp.array([[-5., -2.5, 0., 2.5, 5.]])

# %%
import jax

dists = jnp.abs(pairwise_distances(array))
print(dists.squeeze().shape)
cov = jnp.cov(dists.squeeze()) #, rowvar=False)
print(cov)
eigvals = jnp.linalg.eigvalsh(cov)
print(eigvals)
spread = jnp.sum(jnp.sqrt(jnp.maximum(eigvals, 0.)))
print(spread)
jax.value_and_grad(measure_of_spread)(array)
# Out:
# (5, 5)
# [[ 15.625   9.375   0.     -9.375 -15.625]
#  [  9.375   8.125   2.5    -4.375  -9.375]
#  [  0.      2.5     4.375   2.5     0.   ]
#  [ -9.375  -4.375   2.5     8.125   9.375]
#  [-15.625  -9.375   0.      9.375  15.625]]
# [4.3331872e-07 5.1318276e-01 9.1186106e-01 7.6118164e+00 4.2838135e+01]
# 10.975977
# (DeviceArray(10.975977, dtype=float32),
#  DeviceArray([[-9.7341973e-01, -2.4822432e-01, -2.3841858e-07,
#                 2.4822491e-01,  9.7341949e-01]], dtype=float32))

# %%
array
# Out:
# DeviceArray([[-5. , -2.5,  0. ,  2.5,  5. ]], dtype=float32)

# %%
jax.value_and_grad(measure_of_spread)(array)
# Out:
# (DeviceArray(10.975977, dtype=float32),
#  DeviceArray([[-9.7341973e-01, -2.4822432e-01, -2.3841858e-07,
#                 2.4822491e-01,  9.7341949e-01]], dtype=float32))

# %%
jnp.mean(jnp.abs(pairwise_distances(array)))
# Out:
# DeviceArray(4., dtype=float32)

# %%
def pairwise_distances(points):
    """
    Calculates the pairwise distances between a set of points.
    
    Args:
        points: an array of shape (n_points, n_dims) containing the coordinates of the points
        
    Returns:
        dists: an array of shape (n_points, n_points) containing the pairwise distances between the points
    """
    diffs = points[:, None, :] - points[None, :, :]
    print(diffs)
    squared_distances = jnp.sum(jnp.square(diffs), axis=-1)
    dists = jnp.sqrt(jnp.asarray(squared_distances))
    return dists

pairwise_distances(array)
# Out:
# [[[0. 0. 0. 0. 0.]]]
# DeviceArray([[0.]], dtype=float32)

# %%
abs(jnp.subtract(array, array.T))
# Out:
# DeviceArray([[ 0. ,  2.5,  5. ,  7.5, 10. ],
#              [ 2.5,  0. ,  2.5,  5. ,  7.5],
#              [ 5. ,  2.5,  0. ,  2.5,  5. ],
#              [ 7.5,  5. ,  2.5,  0. ,  2.5],
#              [10. ,  7.5,  5. ,  2.5,  0. ]], dtype=float32)
